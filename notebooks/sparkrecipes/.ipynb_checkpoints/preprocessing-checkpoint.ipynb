# %%
import pandas as pd
import re
from tqdm.notebook import tqdm
from difflib import SequenceMatcher

pd.set_option('max_colwidth', 40)
pd.set_option('display.max_rows', 40)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !ls ../..
# Out:
# data      models    notebooks seefood   spiders

# %%
df = pd.read_csv("../../data/sparkrecipes_complete_tmp.csv")

# %%
df.head(5)
# Out:
#    id                           title  \
# 0   5        20-Minute Chicken Creole
# 1   3  Caribbean Black Beans and Rice
# 2   6     Beef and Vegetable Stir-Fry
# 3   7          Italian Vegetable Bake
# 4   8             Carrot-Raisin Bread
#
#                                  image_url  \
# 0  https://sparkpeo.hs.llnwd.net/e1/res...
# 1                                      NaN
# 2                                      NaN
# 3  https://sparkpeo.hs.llnwd.net/e1/res...
# 4                                      NaN
#
#                                ingredients  \
# 0  nonstick cooking spray as needed|||4...
# 1  |||1 lb. dry black beans|||7 cups wa...
# 2  |||\n2 tablespoons dry red wine |||\...
# 3  |||1 can (28 oz.) whole tomatoes  ||...
# 4  |||1-1/2 cups sifted all-purpose flo...
#
#                                        url  servings  \
# 0  https://recipes.sparkpeople.com/reci...       1.0
# 1  https://recipes.sparkpeople.com/reci...       NaN
# 2  https://recipes.sparkpeople.com/reci...       NaN
# 3  https://recipes.sparkpeople.com/reci...       NaN
# 4  https://recipes.sparkpeople.com/reci...       NaN
#
#                        ingredient_calories Calories Total Fat Saturated Fat  \
# 0  152 calories of Chicken Breast (cook...    269.3     6.3 g         1.9 g
# 1  227 calories of Beans, black, (1 cup...    479.6     3.9 g         0.6 g
# 2  100 calories of Beef, round steak, (...    245.5    10.2 g         1.5 g
# 3  8 calories of Canned Tomatoes, (0.25...     37.2     0.2 g         0.1 g
# 4  40 calories of Wheat flour, white, b...    100.1     1.4 g         0.1 g
#
#    ...    Iron Magnesium Manganese  Niacin Pantothenic Acid Phosphorus  \
# 0  ...  15.7 %    17.6 %    19.6 %  78.2 %           15.1 %     33.0 %
# 1  ...  32.9 %    36.8 %    81.8 %  16.9 %           11.1 %     32.9 %
# 2  ...  11.5 %     8.9 %    13.1 %  22.1 %            6.9 %     21.8 %
# 3  ...   4.0 %     8.3 %    21.9 %   4.6 %            2.2 %      4.5 %
# 4  ...   3.5 %     1.3 %     7.5 %   4.3 %            0.6 %      2.1 %
#
#   Riboflavin Selenium Thiamin    Zinc
# 0     13.9 %   33.3 %  16.8 %  12.0 %
# 1      8.2 %   20.5 %  47.2 %  18.9 %
# 2     16.2 %   25.3 %  11.0 %  16.7 %
# 3      3.8 %    1.2 %   6.6 %   2.4 %
# 4      3.8 %    6.6 %   6.7 %   1.0 %
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (64325, 38)

# %%
df.dtypes
# Out:
# id                       int64
# title                   object
# image_url               object
# ingredients             object
# url                     object
# servings               float64
# ingredient_calories     object
# Calories                object
# Total Fat               object
# Saturated Fat           object
# Polyunsaturated Fat     object
# Monounsaturated Fat     object
# Cholesterol             object
# Sodium                  object
# Potassium               object
# Total Carbohydrate      object
# Dietary Fiber           object
# Sugars                  object
# Protein                 object
# Vitamin A               object
# Vitamin B-12            object
# Vitamin B-6             object
# Vitamin C               object
# Vitamin D               object
# Vitamin E               object
# Calcium                 object
# Copper                  object
# Folate                  object
# Iron                    object
# Magnesium               object
# Manganese               object
# Niacin                  object
# Pantothenic Acid        object
# Phosphorus              object
# Riboflavin              object
# Selenium                object
# Thiamin                 object
# Zinc                    object
# dtype: object

# %%
df.isna().mean().plot.bar(figsize=(10, 5));

# %%
df.servings.fillna(0.0).hist(bins=80, figsize=(10, 5));

# %%
df["servings_avail"] = df.servings.map(lambda s: s > 0)

# %%
df[["servings_avail", "Calories"]].groupby(by=["servings_avail"])

# %%
df[df.servings > 0][["id", "title", "servings", "Calories"]].sample(5)
# Out:
#            id                            title  servings Calories
# 24048   89702                     fruity snack       4.0    210.3
# 42279  154612     Chuckwagon BBQ Rice Round Up       6.0    386.2
# 42199  154294                       Home Fries       3.0    206.3
# 35499  129246                Apple Pie Pancake       1.0    192.7
# 11512   43896  Fruity Vanilla Protein Smoothie       4.0    118.1

# %%
df = df[~df["Calories"].isnull()]

# %% [markdown]
# ## Preprocess Total Calories

# %%
df["total_calories"] = df["Calories"].apply(lambda x: float(x.replace(",", ""))) 
df = df[df.total_calories <= 1000]

# %%
df.head()
# Out:
#    id                           title  \
# 0   5        20-Minute Chicken Creole
# 1   3  Caribbean Black Beans and Rice
# 2   6     Beef and Vegetable Stir-Fry
# 3   7          Italian Vegetable Bake
# 4   8             Carrot-Raisin Bread
#
#                                  image_url  \
# 0  https://sparkpeo.hs.llnwd.net/e1/res...
# 1                                      NaN
# 2                                      NaN
# 3  https://sparkpeo.hs.llnwd.net/e1/res...
# 4                                      NaN
#
#                                ingredients  \
# 0  nonstick cooking spray as needed|||4...
# 1  |||1 lb. dry black beans|||7 cups wa...
# 2  |||\n2 tablespoons dry red wine |||\...
# 3  |||1 can (28 oz.) whole tomatoes  ||...
# 4  |||1-1/2 cups sifted all-purpose flo...
#
#                                        url  servings  \
# 0  https://recipes.sparkpeople.com/reci...       1.0
# 1  https://recipes.sparkpeople.com/reci...       NaN
# 2  https://recipes.sparkpeople.com/reci...       NaN
# 3  https://recipes.sparkpeople.com/reci...       NaN
# 4  https://recipes.sparkpeople.com/reci...       NaN
#
#                        ingredient_calories Calories Total Fat Saturated Fat  \
# 0  152 calories of Chicken Breast (cook...    269.3     6.3 g         1.9 g
# 1  227 calories of Beans, black, (1 cup...    479.6     3.9 g         0.6 g
# 2  100 calories of Beef, round steak, (...    245.5    10.2 g         1.5 g
# 3  8 calories of Canned Tomatoes, (0.25...     37.2     0.2 g         0.1 g
# 4  40 calories of Wheat flour, white, b...    100.1     1.4 g         0.1 g
#
#    ... Manganese  Niacin Pantothenic Acid Phosphorus Riboflavin Selenium  \
# 0  ...    19.6 %  78.2 %           15.1 %     33.0 %     13.9 %   33.3 %
# 1  ...    81.8 %  16.9 %           11.1 %     32.9 %      8.2 %   20.5 %
# 2  ...    13.1 %  22.1 %            6.9 %     21.8 %     16.2 %   25.3 %
# 3  ...    21.9 %   4.6 %            2.2 %      4.5 %      3.8 %    1.2 %
# 4  ...     7.5 %   4.3 %            0.6 %      2.1 %      3.8 %    6.6 %
#
#   Thiamin    Zinc servings_avail total_calories
# 0  16.8 %  12.0 %           True          269.3
# 1  47.2 %  18.9 %          False          479.6
# 2  11.0 %  16.7 %          False          245.5
# 3   6.6 %   2.4 %          False           37.2
# 4   6.7 %   1.0 %          False          100.1
#
# [5 rows x 40 columns]

# %%
df_base = df[["id", "title", "image_url", "total_calories", "url", "servings"]]
df_base.head()
# Out:
#    id                           title  \
# 0   5        20-Minute Chicken Creole
# 1   3  Caribbean Black Beans and Rice
# 2   6     Beef and Vegetable Stir-Fry
# 3   7          Italian Vegetable Bake
# 4   8             Carrot-Raisin Bread
#
#                                  image_url  total_calories  \
# 0  https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 1                                      NaN           479.6
# 2                                      NaN           245.5
# 3  https://sparkpeo.hs.llnwd.net/e1/res...            37.2
# 4                                      NaN           100.1
#
#                                        url  servings
# 0  https://recipes.sparkpeople.com/reci...       1.0
# 1  https://recipes.sparkpeople.com/reci...       NaN
# 2  https://recipes.sparkpeople.com/reci...       NaN
# 3  https://recipes.sparkpeople.com/reci...       NaN
# 4  https://recipes.sparkpeople.com/reci...       NaN

# %%
df_base.columns = ["recipe_id", "title", "image_url", "total_calories", "url", "servings"]
df_base.head()
# Out:
#    recipe_id                           title  \
# 0          5        20-Minute Chicken Creole
# 1          3  Caribbean Black Beans and Rice
# 2          6     Beef and Vegetable Stir-Fry
# 3          7          Italian Vegetable Bake
# 4          8             Carrot-Raisin Bread
#
#                                  image_url  total_calories  \
# 0  https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 1                                      NaN           479.6
# 2                                      NaN           245.5
# 3  https://sparkpeo.hs.llnwd.net/e1/res...            37.2
# 4                                      NaN           100.1
#
#                                        url  servings
# 0  https://recipes.sparkpeople.com/reci...       1.0
# 1  https://recipes.sparkpeople.com/reci...       NaN
# 2  https://recipes.sparkpeople.com/reci...       NaN
# 3  https://recipes.sparkpeople.com/reci...       NaN
# 4  https://recipes.sparkpeople.com/reci...       NaN

# %%
df_base.total_calories.hist(bins=200, figsize=(10, 7))

# %%
df_base.describe()
# Out:
#            recipe_id  total_calories      servings
# count   63547.000000    63547.000000  63071.000000
# mean   117337.339969      230.920662      8.174311
# std     66654.167785      140.671971     10.157424
# min         3.000000        0.000000      1.000000
# 25%     61950.000000      129.600000      4.000000
# 50%    117481.000000      206.500000      6.000000
# 75%    176108.000000      305.200000     10.000000
# max    230141.000000      999.900000    255.000000

# %% [markdown]
# ## Preprocess Ingredients

# %%
df.ingredient_calories.values[0].split("|||")
# Out:
# ['152 calories of Chicken Breast (cooked), no skin, roasted, (0.53 breast, bone and skin removed)',
#  '69 calories of Nestle Chef Mate Hot Dog Chili Sauce, (0.25 cup)',
#  '19 calories of Red Ripe Tomatoes, (0.50 cup, chopped or sliced)',
#  '13 calories of Sweet peppers (bell), (0.33 cup, chopped)',
#  '6 calories of Lemon juice, (1 fl oz)',
#  '4 calories of Onions, raw, (0.06 cup, chopped)',
#  '3 calories of Celery, raw, (0.15 cup, diced)',
#  '2 calories of Garlic, (0.50 clove)',
#  '1 calories of Parsley, (0.50 tbsp)',
#  '0 calories of Basil, (0.50 tbsp)',
#  '0 calories of Peppers, sweet, red, fresh, (0.06 tbsp)',
#  '0 calories of Salt, (0.06 tsp)']

# %%
df_ing_cal = pd.DataFrame(df.ingredient_calories.str.rsplit(r"|||").tolist()).stack().reset_index([0]).reset_index(drop=True)
df_ing_cal.columns = ["recipe_id", "ingredient"]
df_ing_cal
# Out:
#         recipe_id                               ingredient
# 0               0  152 calories of Chicken Breast (cook...
# 1               0  69 calories of Nestle Chef Mate Hot ...
# 2               0  19 calories of Red Ripe Tomatoes, (0...
# 3               0  13 calories of Sweet peppers (bell),...
# 4               0     6 calories of Lemon juice, (1 fl oz)
# ...           ...                                      ...
# 445980      63546         8 calories of Basil, (0.75 tbsp)
# 445981      63546         2 calories of Garlic, (0.50 tsp)
# 445982      63546   1 calories of Fennel seed, (0.06 tbsp)
# 445983      63546           0 calories of Salt, (0.06 tsp)
# 445984      63546  0 calories of Crushed Red Pepper, (0...
#
# [445985 rows x 2 columns]

# %%
df_ing_cal_fine = pd.DataFrame(df_ing_cal.ingredient.str.split("calories of").tolist(), index=df_ing_cal.index)
df_ing_cal_fine.columns = ["calories", "ingredient"]
df_ing_cal_fine = df_ing_cal_fine.join(df_ing_cal[["recipe_id"]])
df_ing_cal_fine
# Out:
#        calories                               ingredient  recipe_id
# 0          152    Chicken Breast (cooked), no skin, r...          0
# 1           69    Nestle Chef Mate Hot Dog Chili Sauc...          0
# 2           19    Red Ripe Tomatoes, (0.50 cup, chopp...          0
# 3           13    Sweet peppers (bell), (0.33 cup, ch...          0
# 4            6                    Lemon juice, (1 fl oz)          0
# ...         ...                                      ...        ...
# 445980       8                        Basil, (0.75 tbsp)      63546
# 445981       2                        Garlic, (0.50 tsp)      63546
# 445982       1                  Fennel seed, (0.06 tbsp)      63546
# 445983       0                          Salt, (0.06 tsp)      63546
# 445984       0        Crushed Red Pepper, (0.25 serving)      63546
#
# [445985 rows x 3 columns]

# %%
def extract_addon(input_str):
    open_bracket_ctr = 0
    inner_chars = []
    bracket_text = []
    for c in input_str:
        if c == "(":
            open_bracket_ctr += 1
            inner_chars.append("(")
        elif c == ")":
            open_bracket_ctr -= 1
            inner_chars.append(")")
            if open_bracket_ctr == 0:
                bracket_text.append(inner_chars)
                inner_chars = []
        elif open_bracket_ctr >= 1:
            inner_chars.append(c)
    result = ["".join(x).strip() for x in bracket_text]
    if len(result) > 0:
        return result[-1][1:-1]
    else:
        return None

# %%
extract_addon("balsamic vinegar, (0.08 tablespoon)")
# Out:
# '0.08 tablespoon'

# %%
extract_addon('Sweet peppers (bell), (0.17 medium (approx 2-3/4" long, 2-1/2" dia))')
# Out:
# '0.17 medium (approx 2-3/4" long, 2-1/2" dia)'

# %%
def extract_amount(ingredient):
    amount_p = extract_addon(ingredient)
    amount_p_addon = extract_addon(amount_p) if amount_p else None
    amount_pp = amount_p.replace(f"({amount_p_addon})", "") if amount_p else None
    amount_ppp = amount_pp.split(",")[0] if amount_pp else None
    
    if amount_ppp:
        match = re.search(r'([0-9]+(\.[0-9]+)?)\s(.*)', amount_ppp, re.IGNORECASE)
        if match:
            return match.group(1), match.group(3), amount_p_addon
    return amount_ppp, None, amount_p_addon

def process_ingredient(ingredient):
    ingredient_p = ingredient.replace(f"({extract_addon(ingredient)})", "")[:-2]
    ingredient_p_addon = extract_addon(ingredient_p)
    ingredient_pp = ingredient_p.replace(f"({ingredient_p_addon})", "") if ingredient else None
    ingredient_ppp = ingredient_pp.split(",")[0] if ingredient_pp else None
    ingredient_pp_addon =  ",".join(ingredient_pp.split(",")[1:])
    ingredient_pp_addon_p = None if ingredient_pp_addon == "" else ingredient_pp_addon
    return ingredient_ppp, ingredient_pp_addon_p, ingredient_p_addon

def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

# %%
df_fine_amount = pd.DataFrame(df_ing_cal_fine["ingredient"].map(lambda x: extract_amount(x)).tolist(), index=df_ing_cal_fine.index)
df_fine_amount.columns = ["amount", "unit", "unit_addon"]
df_fine_ingredient = pd.DataFrame(df_ing_cal_fine["ingredient"].map(lambda x: process_ingredient(x)).tolist(), index=df_ing_cal_fine.index)
df_fine_ingredient.columns = ["ingredient_name", "ingredient_addon_a", "ingredient_addon_b"]

# %%
df_ing_complete = df_ing_cal_fine[["recipe_id", "ingredient", "calories"]].join(df_fine_amount).join(df_fine_ingredient)
df_ing_complete["calories"] = df_ing_complete["calories"].str.replace(",", "").astype(float)
df_ing_complete["amount"] = df_ing_complete["amount"].map(lambda x: float(x) if x and isfloat(x) else None)

# %%
df_ing_complete
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 0               0   Chicken Breast (cooked), no skin, r...     152.0    0.53
# 1               0   Nestle Chef Mate Hot Dog Chili Sauc...      69.0    0.25
# 2               0   Red Ripe Tomatoes, (0.50 cup, chopp...      19.0    0.50
# 3               0   Sweet peppers (bell), (0.33 cup, ch...      13.0    0.33
# 4               0                   Lemon juice, (1 fl oz)       6.0    1.00
# ...           ...                                      ...       ...     ...
# 445980      63546                       Basil, (0.75 tbsp)       8.0    0.75
# 445981      63546                       Garlic, (0.50 tsp)       2.0    0.50
# 445982      63546                 Fennel seed, (0.06 tbsp)       1.0    0.06
# 445983      63546                         Salt, (0.06 tsp)       0.0    0.06
# 445984      63546       Crushed Red Pepper, (0.25 serving)       0.0    0.25
#
#            unit unit_addon                        ingredient_name  \
# 0        breast       None                        Chicken Breast
# 1           cup       None   Nestle Chef Mate Hot Dog Chili Sauce
# 2           cup       None                      Red Ripe Tomatoes
# 3           cup       None                         Sweet peppers
# 4         fl oz       None                            Lemon juice
# ...         ...        ...                                    ...
# 445980     tbsp       None                                  Basil
# 445981      tsp       None                                 Garlic
# 445982     tbsp       None                            Fennel seed
# 445983      tsp       None                                   Salt
# 445984  serving       None                     Crushed Red Pepper
#
#        ingredient_addon_a ingredient_addon_b
# 0        no skin, roasted             cooked
# 1                    None               None
# 2                    None               None
# 3                    None               bell
# 4                    None               None
# ...                   ...                ...
# 445980               None               None
# 445981               None               None
# 445982               None               None
# 445983               None               None
# 445984               None               None
#
# [445985 rows x 9 columns]

# %% [markdown]
# ### Analyze calories and amounts

# %%
df_ing_complete.dtypes
# Out:
# recipe_id               int64
# ingredient             object
# calories              float64
# amount                float64
# unit                   object
# unit_addon             object
# ingredient_name        object
# ingredient_addon_a     object
# ingredient_addon_b     object
# dtype: object

# %%
df_ing_complete[["calories", "amount"]].describe()
# Out:
#             calories         amount
# count  445985.000000  445856.000000
# mean       33.194401       2.502989
# std        63.654966     108.686405
# min         0.000000       0.000000
# 25%         2.000000       0.100000
# 50%        12.000000       0.250000
# 75%        40.000000       0.630000
# max     18462.000000   34811.000000

# %%
df_ing_complete[["calories", "amount"]].hist(bins=200, figsize=(20, 7), log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1313aa588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132f5c6d8>]],
#       dtype=object)

# %%
df_ing_complete[df_ing_complete.calories < 1000][["calories", "amount"]].hist(bins=200, figsize=(20, 7), log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11deeda58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dfa6ba8>]],
#       dtype=object)

# %%
df_ing_complete.isna().mean().plot.bar(log=True, figsize=(10, 7))

# %% [markdown]
# ### Normalize calories

# %%
df_ing_complete["norm_calories"] = df_ing_complete["calories"] /  df_ing_complete["amount"]

# %%
df_ing_complete["norm_calories"].hist(bins=100, log=True)

# %%
df_ing_complete[df_ing_complete.norm_calories > 1000]
# Out:
#         recipe_id                             ingredient  calories  amount  \
# 88              9                  Olive Oil, (0.01 cup)      19.0    0.01
# 112            12                 Canola Oil, (0.02 cup)      39.0    0.02
# 140            16                 Canola Oil, (0.04 cup)      77.0    0.04
# 310            39                  Olive Oil, (0.01 cup)      19.0    0.01
# 328            42            Margarine, soft, (0.02 cup)      33.0    0.02
# ...           ...                                    ...       ...     ...
# 445740      63511            Margarine, soft, (0.04 cup)      65.0    0.04
# 445741      63511            Margarine, soft, (0.02 cup)      33.0    0.02
# 445748      63512                  Olive Oil, (0.03 cup)      57.0    0.03
# 445817      63523   Beef chuck, arm pot roast, (0.50 lb)     672.0    0.50
# 445955      63543                  Olive Oil, (0.08 cup)     153.0    0.08
#
#        unit unit_addon ingredient_name ingredient_addon_a ingredient_addon_b  \
# 88      cup       None       Olive Oil               None               None
# 112     cup       None      Canola Oil               None               None
# 140     cup       None      Canola Oil               None               None
# 310     cup       None       Olive Oil               None               None
# 328     cup       None       Margarine               soft               None
# ...     ...        ...             ...                ...                ...
# 445740  cup       None       Margarine               soft               None
# 445741  cup       None       Margarine               soft               None
# 445748  cup       None       Olive Oil               None               None
# 445817   lb       None      Beef chuck      arm pot roast               None
# 445955  cup       None       Olive Oil               None               None
#
#         norm_calories
# 88             1900.0
# 112            1950.0
# 140            1925.0
# 310            1900.0
# 328            1650.0
# ...               ...
# 445740         1625.0
# 445741         1650.0
# 445748         1900.0
# 445817         1344.0
# 445955         1912.5
#
# [6475 rows x 10 columns]

# %% [markdown]
# ### Normalize units

# %%
df_ing_complete["unit"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_complete['unit'].unique()
# Out:
# array(['breast', 'cup', 'fl oz', 'clove', 'tbsp', 'tsp', 'medium ',
#        'fruit ', 'slice', 'oz', 'cup slices', 'stalk', 'can', 'eggplant',
#        'medium', 'oz ', 'large', 'cup elbow shaped', 'fillet', 'can ',
#        'cup kernels', 'cup diced', 'tbsp chopped', 'large whole ',
#        'large ', 'fruit without seeds', 'sprigs', 'head', 'unit ', 'cup ',
#        'small', 'cherry', 'package  yields', '1tsp', 'glass ',
#        'lemon yields', 'grams', 'serving', None, 'small ', 'leaf',
#        'tsp or 1 packet', 'tsp unpacked', 'fruit without skin',
#        'patty (4 oz', 'tortilla ', 'tsp packed', 'lb', 'Italian tomato',
#        'dash', 'cup chips ', 'medium (2-3/4" dia) ', 'pack ', 'cube ',
#        'stick', 'package ', 'crust', 'scoop', 'cloves', 'medium whole ',
#        'pepper', 'lime yields', 'ear', 'Cup', 'teaspoon', 'ice cube ',
#        'fruit without skin and seeds', 'carrot ', 'leaves', 'sweetpotato',
#        'artichoke', 'slice ', 'inner leaf', 'square ', 'pita', 'muffin',
#        'unit', 'bunch', 'pear', 'prune', 'slices ', 'ounces',
#        'large (3-1/4" dia) ', 'cup sprigs', 'cup cherry tomatoes',
#        'beet ', 'potato ', 'tomato', 'jumbo', 'medium (2-1/2" dia) ',
#        'fruit', 'container', 'tsp chopped', 'cucumber ',
#        'cup pieces or chips', 'plum tomato', 'leek', 'watermelon balls',
#        'cup mini chips', 'Serving', 'tortilla', 'quart', 'can  yields',
#        'cup of miniature', 'extra large', 'cup small shells', 'half',
#        'slice crust not eaten', 'beans ', 'fruit without refuse', 'bulb',
#        'mushrooms', 'tbsp ', 'packet ', 'pint as purchased', 'wedge',
#        'roll', 'wrapper', 'gram', 'medium slices', 'sheet dough',
#        'leaf outer', 'ounce', 'serving ', 'thigh', 'tablespoon', 'fl. oz',
#        'tbs', 'slice or wedge', 'grape', 'pat ', 'spear', 'cup chips',
#        'cracker', 'wedge yields', 'serving 2 pops', 'small (2-1/2" dia) ',
#        'small box ', 'carrot', 'drumstick', 'piece', 'Tbspn',
#        'miniature box ', 'cup shelled ', 'berries', 'spear ',
#        'container ', 'cup pieces', 'strips', 'block', 'cracker ',
#        'can or bottle ', 'rings', 'cake', 'biscuit ', 'small (2" dia) ',
#        'bag ', 'parsnip ', 'mushroom', 'berry', 'pie shell ',
#        'raspberries', 'package', 'cubic inch', 'piece ', 'tube cake ',
#        'chop', 'packet', 'frankfurter', 'package yields', 'roll ',
#        'squash ', 'large (2-3/4" dia) ', 'chicken', 'peanut',
#        'extra large ', 'ring ', 'cookie', 'croissant', 'slices', 'wedge ',
#        'leaf inner', 'bar ', 'wedge or slice ', 'raisins',
#        'slice or ring  with liquid', 'anchovies', 'wafer', 'date',
#        'patty', 'beets ', 'Triscuit Bits', 'link', 'stalks',
#        'individual ', 'breakfast treat ', 'stick ', 'link ', 'melon',
#        'jigger 1.5 fl oz', 'unit 2 large or 5 small', 'apricot',
#        'muffin ', 'portion', 'ladyfinger', 'cube', 'almond', 'Serving ',
#        'cubes', 'strip', 'pouch', 'cup slices ', 'leg', 'portion ',
#        'Gherkin ', 'serving 1/2 cup', 'wing', 'floweret', 'extra small ',
#        'radish ', 'head ', 'waterchestnuts', 'cup shredded', 'cherry ',
#        'miniatures', 'melon ',
#        'large rectangular piece or 2 squares or 4 small rectangular pieces',
#        'can (29 oz) ', 'cup large chips',
#        'fruit 2-1/4" high x 2-1/2" dia', 'single stick',
#        'individual packet', 'small whole ', 'small Gherkin ',
#        'package yield', 'pieces', 'spear tip ', 'strip ', 'waffle',
#        'pods ', 'halves', 'bagel ', 'regular', 'crispbread',
#        'super colossal', 'lump ', 'roll (pan', 'g', 'biscuit',
#        'frankfurter ', 'tsp brownulated', 'shoot', 'cup spiral shaped',
#        'toast', 'bar', 'pomegranate ', 'fruit 3-3/8" high x 3" diameter',
#        'fruit yields', 'fluid ounce', 'bunch cooked', 'drink box ',
#        'package yield ', 'cup oyster crackers', 'cup whole kernels',
#        'biscuits ', 'serving 1 pop', 'plum with liquid', 'pad',
#        'sandwich', 'steak', 'oz with bone', 'jar', 'sheet', 'saltines',
#        'bird whole', 'sheets', 'envelope', 'sprout', 'recipe yield',
#        'flowerets', 'pizza ', 'bird', 'medium slice ', 'patty ',
#        'sausage ', 'anchovy', 'brownie ', 'each', 'cup sections', 'yam',
#        'root', 'oz. can = 4 servings', 'sardines', 'miniature ', 'matzo',
#        'fig', 'slice thin', 'snack size ', 'miniature', 'midget Gherkin ',
#        'pimiento', 'fl oz ', 'sausage',
#        'tsp or 500 mg = 1 svg; 1/4 tsp =1 tsp sugar', 'oz.',
#        'cookie  rolled cookie dough', 'nuts', 'cone', "Butterfinger BB's",
#        'shell', 'flower', 'mL', 'quail', 'sausages ',
#        'slice (4" dia x 1/8" thick) ', 'tart shell', 'slice (1 oz) ',
#        'egg', 'serving 28 pieces', 'bun', 'cup chopped or diced', 'crab',
#        'liver', 'oz cooked', 'gumdrops', 'melba round',
#        'round waffle (4" dia) ', 'individual box ', '1/2 Serv'],
#       dtype=object)

# %%
f"Number of unique units: {df_ing_complete['unit'].unique().shape[0]}"
# Out:
# 'Number of unique units: 329'

# %%
df_ing_complete[df_ing_complete["unit"].isna()]
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 264            33   Baked Potato, with skin, (0.50 larg...     139.0     NaN
# 6269          844   Baked Potato, with skin, (1 large (...     278.0     NaN
# 10199        1446   Baked Potato, with skin, (1 large (...     278.0     NaN
# 15869        2331   Baked Potato, with skin, (1 large (...     278.0     NaN
# 15880        2332   Great Value Sugar Free Lemonade Nat...       0.0     NaN
# ...           ...                                      ...       ...     ...
# 430076      61339   Baked Potato, with skin, (0.30 larg...      83.0     NaN
# 435588      62102   Smart & Delicious Soft Wraps (LaTor...     100.0     NaN
# 436878      62286   Mini M&Ms (12 oz package, (0.16 ser...      34.0     NaN
# 442977      63128   Bush's Cannellini (White Kidney) Be...      39.0     NaN
# 444205      63304   Baked Potato, with skin, (0.50 larg...     139.0     NaN
#
#         unit unit_addon                          ingredient_name  \
# 264     None       None                             Baked Potato
# 6269    None       None                             Baked Potato
# 10199   None       None                             Baked Potato
# 15869   None       None                             Baked Potato
# 15880   None       None   Great Value Sugar Free Lemonade Nat...
# ...      ...        ...                                      ...
# 430076  None       None                             Baked Potato
# 435588  None       None   Smart & Delicious Soft Wraps  Made ...
# 436878  None       None                 Mini M&Ms (12 oz package
# 442977  None       None   Bush's Cannellini  Beans 15.5 oz ca...
# 444205  None       None                             Baked Potato
#
#                              ingredient_addon_a ingredient_addon_b  \
# 264      with skin, (0.50 large (3" to 4-1/4...               None
# 6269      with skin, (1 large (3" to 4-1/4" dia               None
# 10199     with skin, (1 large (3" to 4-1/4" dia               None
# 15869     with skin, (1 large (3" to 4-1/4" dia               None
# 15880                                  (0.20 cu               None
# ...                                         ...                ...
# 430076   with skin, (0.30 large (3" to 4-1/4...               None
# 435588                                (1 servin               None
# 436878                             (0.16 servin               None
# 442977                             (0.35 servin               None
# 444205   with skin, (0.50 large (3" to 4-1/4...               None
#
#         norm_calories
# 264               NaN
# 6269              NaN
# 10199             NaN
# 15869             NaN
# 15880             NaN
# ...               ...
# 430076            NaN
# 435588            NaN
# 436878            NaN
# 442977            NaN
# 444205            NaN
#
# [129 rows x 10 columns]

# %% [markdown]
# * lowercase vs. uppercase (x)
# * strip (x)
# * tbsp, tsp, tablespoon, tbs, Tbspn
# * cup X
# * tbsp X
# * 1tsp
# * None?
# * X or Y

# %%
MIN_UNIT_COUNT = 300

tablespoon_abbrev = ["tbsp", "tablespoon", "tbs"]
teaspoon_abbrev = ["tsp", "teaspoon"]
cup_abbrev = ["cup"]
oz_abbrev = ["oz", "fl oz"]

def norm_unit(abbrev, target, unit):
    if any([a in unit for a in abbrev]):
        return target
    else:
        return unit

# %%
df_ing_complete["norm_unit"] = (
    df_ing_complete["unit"]
    .str.strip()
    .str.lower()
    .map(lambda x: norm_unit(tablespoon_abbrev, "tablespoon", x) if x else None)
    .map(lambda x: norm_unit(teaspoon_abbrev, "teaspoon", x) if x else None)
    .map(lambda x: norm_unit(cup_abbrev, "cup", x) if x else None)
    .map(lambda x: norm_unit(oz_abbrev, "oz", x) if x else None)
)
unit_counts = df_ing_complete["norm_unit"].value_counts()
df_ing_complete["norm_unit"] = df_ing_complete["norm_unit"].map(lambda x: "generic_unit" if x and unit_counts[x] <= MIN_UNIT_COUNT else x)

# %%
f"Number of unique (normalized) units: {df_ing_complete['norm_unit'].unique().shape[0]}"
# Out:
# 'Number of unique (normalized) units: 49'

# %%
df_ing_complete["norm_unit"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_complete["norm_unit"].unique()
# Out:
# array(['breast', 'cup', 'oz', 'clove', 'tablespoon', 'teaspoon', 'medium',
#        'fruit', 'slice', 'stalk', 'can', 'eggplant', 'large', 'fillet',
#        'large whole', 'generic_unit', 'head', 'unit', 'small',
#        'package  yields', 'lemon yields', 'grams', 'serving', None,
#        'tortilla', 'lb', 'dash', 'medium (2-3/4" dia)', 'stick',
#        'package', 'crust', 'cloves', 'medium whole', 'pepper',
#        'lime yields', 'fruit without skin and seeds', 'carrot', 'leaves',
#        'bunch', 'ounces', 'jumbo', 'plum tomato', 'can  yields',
#        'extra large', 'gram', 'medium slices', 'ounce', 'thigh', 'piece'],
#       dtype=object)

# %%
df_ing_complete["norm_unit"].value_counts()
# Out:
# cup            162737
# teaspoon        62151
# tablespoon      59581
# oz              31927
# serving         25474
#                 ...
# crust             339
# extra large       313
# bunch             312
# fillet            310
# piece             304
# Name: norm_unit, Length: 48, dtype: int64

# %% [markdown]
# ### Normalize ingredient names

# %%
df_ing_complete["norm_ingredient_name"] = df_ing_complete["ingredient_name"].str.strip().str.lower()
df_ing_complete["norm_ingredient_name"]
# Out:
# 0                               chicken breast
# 1         nestle chef mate hot dog chili sauce
# 2                            red ripe tomatoes
# 3                                sweet peppers
# 4                                  lemon juice
#                           ...
# 445980                                   basil
# 445981                                  garlic
# 445982                             fennel seed
# 445983                                    salt
# 445984                      crushed red pepper
# Name: norm_ingredient_name, Length: 445985, dtype: object

# %%
df_ing_complete["norm_ingredient_name"].unique().shape
# Out:
# (23528,)

# %%
df_ing_complete["norm_ingredient_name"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_stats = df_ing_complete[["norm_ingredient_name", "calories"]].groupby(["norm_ingredient_name"]).agg(["count", "mean", "sum", "std", "median"])
df_ing_stats.sort_values(by=[("calories", "std")], ascending=True)
# Out:
#                                          calories
#                                             count   mean    sum  std median
# norm_ingredient_name
#                                                24    0.0    0.0  0.0    0.0
# safeway 100% natural tomato paste               2   17.0   34.0  0.0   17.0
# fiber wise penne pasta                          2  170.0  340.0  0.0  170.0
# fiber powder                                    4    0.0    0.0  0.0    0.0
# safeway cut green beans                         2    2.0    4.0  0.0    2.0
# ...                                           ...    ...    ...  ...    ...
# zuciini                                         1    0.0    0.0  NaN    0.0
# zumo sausage                                    1  480.0  480.0  NaN  480.0
# zylitol sweetener                               1    1.0    1.0  NaN    1.0
# ~lilydale frozen boneless skinless ch...        1   40.0   40.0  NaN   40.0
# 고추장 - hot pepper paste                          1    8.0    8.0  NaN    8.0
#
# [23528 rows x 5 columns]

# %%
with pd.option_context('display.max_rows', 10):
    df_ing_stats[df_ing_stats["calories", "std"] > 0.0].sample(10)
# Out:
#                                          calories                      \
#                                             count        mean     sum
# norm_ingredient_name
# hormel turkey pepperoni                         6   48.000000   288.0
# hellmann's                                    168   35.761905  6008.0
# yukon gold potatoes                             2   75.000000   150.0
# baileys irish cream                             2   18.500000    37.0
# chipotle tomato salsa                          10    8.900000    89.0
# rice crispies                                   6   37.666667   226.0
# bush light red kidney beans                     2   38.500000    77.0
# ronzoni healthy harvest whole wheat l...        4   64.250000   257.0
# apple butter                                   48   18.270833   877.0
# thomas' 100% whole wheat mini bagel             4  110.000000   440.0
#
#
#                                                 std median
# norm_ingredient_name
# hormel turkey pepperoni                   33.015148   52.5
# hellmann's                                33.335931   25.5
# yukon gold potatoes                       35.355339   75.0
# baileys irish cream                        9.192388   18.5
# chipotle tomato salsa                      7.370361    6.0
# rice crispies                             33.218469   24.5
# bush light red kidney beans                7.778175   38.5
# ronzoni healthy harvest whole wheat l...  17.327723   56.5
# apple butter                              23.360031   10.0
# thomas' 100% whole wheat mini bagel       44.907312  110.0

# %%
df_ing_complete[df_ing_complete.norm_ingredient_name == "ground beef"]
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 117            13            Ground Beef (lean), (0.80 oz)      63.0     0.8
# 203            24               Ground Beef (lean), (2 oz)     157.0     2.0
# 212            25      Ground Beef (extra lean), (2.50 oz)     186.0     2.5
# 505            66                Ground beef, lean, (3 oz)     225.0     3.0
# 561            74             Ground beef, lean, (4.50 oz)     337.0     4.5
# ...           ...                                      ...       ...     ...
# 445767      63515                Ground beef, lean, (2 oz)     150.0     2.0
# 445794      63519                Ground beef, lean, (2 oz)     150.0     2.0
# 445852      63529   Ground beef, extra lean (15% fat) p...     219.0     3.0
# 445873      63532   Ground beef, extra lean (15% fat) p...     146.0     2.0
# 445944      63542             Ground beef, lean, (3.20 oz)     240.0     3.2
#
#        unit unit_addon ingredient_name        ingredient_addon_a  \
# 117      oz       None    Ground Beef                       None
# 203      oz       None    Ground Beef                       None
# 212      oz       None    Ground Beef                       None
# 505      oz       None     Ground beef                      lean
# 561      oz       None     Ground beef                      lean
# ...     ...        ...             ...                       ...
# 445767   oz       None     Ground beef                      lean
# 445794   oz       None     Ground beef                      lean
# 445852   oz       None     Ground beef   extra lean  pan broiled
# 445873   oz       None     Ground beef   extra lean  pan broiled
# 445944   oz       None     Ground beef                      lean
#
#        ingredient_addon_b  norm_calories norm_unit norm_ingredient_name
# 117                  lean      78.750000        oz          ground beef
# 203                  lean      78.500000        oz          ground beef
# 212            extra lean      74.400000        oz          ground beef
# 505                  None      75.000000        oz          ground beef
# 561                  None      74.888889        oz          ground beef
# ...                   ...            ...       ...                  ...
# 445767               None      75.000000        oz          ground beef
# 445794               None      75.000000        oz          ground beef
# 445852            15% fat      73.000000        oz          ground beef
# 445873            15% fat      73.000000        oz          ground beef
# 445944               None      75.000000        oz          ground beef
#
# [3301 rows x 12 columns]

# %% [markdown]
# ### Analyze (approx.) duplicates in ingredient list (WIP)

# %% [raw]
# ingredients = df_ing_complete["norm_ingredient_name"].unique()

# %% [raw]
# ing_similarities = {}
# for i in tqdm(ingredients):
#     ing_similarities[i] = {}
#     for ii in ingredients:
#         ing_similarities[i][ii] = SequenceMatcher(None, i, ii).ratio()

# %% [raw]
# df_ing_similarities = pd.DataFrame(ing_similarities)
# df_ing_similarities.head()

# %% [raw]
# def get_most_similar(ingredient, ratio = 0.9):
#     mask = (df_ing_similarities.loc[ingredient] >= ratio) & (df_ing_similarities.loc[ingredient] != 1.0)
#     return df_ing_similarities.loc[ingredient][mask].index.values

# %% [raw]
# { i: get_most_similar(i) for i in ingredients[:20] if get_most_similar(i).shape[0] }

# %% [markdown]
# ### Analyze long ingredient names

# %%
df_ing_complete[["norm_ingredient_name", "calories"]][df_ing_complete.norm_ingredient_name.str.len() >= 30]["norm_ingredient_name"].unique().shape[0]
# Out:
# 9485

# %% [markdown]
# ### Analyze number of servings

# %%
df_base
# Out:
#        recipe_id                             title  \
# 0              5          20-Minute Chicken Creole
# 1              3    Caribbean Black Beans and Rice
# 2              6       Beef and Vegetable Stir-Fry
# 3              7            Italian Vegetable Bake
# 4              8               Carrot-Raisin Bread
# ...          ...                               ...
# 64320     230127  Ground beef and pepper burrito's
# 64321     230133             Caesar Salad Dressing
# 64322     230131              Tortellini Primavera
# 64323     230134             Tomoto Rice with Beef
# 64324     230141     Shrimp and Scallop Arrabbiata
#
#                                      image_url  total_calories  \
# 0      https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 1                                          NaN           479.6
# 2                                          NaN           245.5
# 3      https://sparkpeo.hs.llnwd.net/e1/res...            37.2
# 4                                          NaN           100.1
# ...                                        ...             ...
# 64320                                      NaN           469.0
# 64321                                      NaN           248.3
# 64322                                      NaN           396.8
# 64323                                      NaN           314.2
# 64324                                      NaN           463.2
#
#                                            url  servings
# 0      https://recipes.sparkpeople.com/reci...       1.0
# 1      https://recipes.sparkpeople.com/reci...       NaN
# 2      https://recipes.sparkpeople.com/reci...       NaN
# 3      https://recipes.sparkpeople.com/reci...       NaN
# 4      https://recipes.sparkpeople.com/reci...       NaN
# ...                                        ...       ...
# 64320  https://recipes.sparkpeople.com/reci...       5.0
# 64321  https://recipes.sparkpeople.com/reci...       6.0
# 64322  https://recipes.sparkpeople.com/reci...       8.0
# 64323  https://recipes.sparkpeople.com/reci...       4.0
# 64324  https://recipes.sparkpeople.com/reci...       4.0
#
# [63547 rows x 6 columns]

# %% [markdown]
# ### Persist dataframes for further analysis

# %%
df_base
# Out:
#        recipe_id                             title  \
# 0              5          20-Minute Chicken Creole
# 1              3    Caribbean Black Beans and Rice
# 2              6       Beef and Vegetable Stir-Fry
# 3              7            Italian Vegetable Bake
# 4              8               Carrot-Raisin Bread
# ...          ...                               ...
# 64320     230127  Ground beef and pepper burrito's
# 64321     230133             Caesar Salad Dressing
# 64322     230131              Tortellini Primavera
# 64323     230134             Tomoto Rice with Beef
# 64324     230141     Shrimp and Scallop Arrabbiata
#
#                                      image_url  total_calories  \
# 0      https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 1                                          NaN           479.6
# 2                                          NaN           245.5
# 3      https://sparkpeo.hs.llnwd.net/e1/res...            37.2
# 4                                          NaN           100.1
# ...                                        ...             ...
# 64320                                      NaN           469.0
# 64321                                      NaN           248.3
# 64322                                      NaN           396.8
# 64323                                      NaN           314.2
# 64324                                      NaN           463.2
#
#                                            url  servings
# 0      https://recipes.sparkpeople.com/reci...       1.0
# 1      https://recipes.sparkpeople.com/reci...       NaN
# 2      https://recipes.sparkpeople.com/reci...       NaN
# 3      https://recipes.sparkpeople.com/reci...       NaN
# 4      https://recipes.sparkpeople.com/reci...       NaN
# ...                                        ...       ...
# 64320  https://recipes.sparkpeople.com/reci...       5.0
# 64321  https://recipes.sparkpeople.com/reci...       6.0
# 64322  https://recipes.sparkpeople.com/reci...       8.0
# 64323  https://recipes.sparkpeople.com/reci...       4.0
# 64324  https://recipes.sparkpeople.com/reci...       4.0
#
# [63547 rows x 6 columns]

# %%
df_base.to_csv("../../data/sparkrecipes_base.csv", index=False)

# %%
df_ing_complete
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 0               0   Chicken Breast (cooked), no skin, r...     152.0    0.53
# 1               0   Nestle Chef Mate Hot Dog Chili Sauc...      69.0    0.25
# 2               0   Red Ripe Tomatoes, (0.50 cup, chopp...      19.0    0.50
# 3               0   Sweet peppers (bell), (0.33 cup, ch...      13.0    0.33
# 4               0                   Lemon juice, (1 fl oz)       6.0    1.00
# ...           ...                                      ...       ...     ...
# 445980      63546                       Basil, (0.75 tbsp)       8.0    0.75
# 445981      63546                       Garlic, (0.50 tsp)       2.0    0.50
# 445982      63546                 Fennel seed, (0.06 tbsp)       1.0    0.06
# 445983      63546                         Salt, (0.06 tsp)       0.0    0.06
# 445984      63546       Crushed Red Pepper, (0.25 serving)       0.0    0.25
#
#            unit unit_addon                        ingredient_name  \
# 0        breast       None                        Chicken Breast
# 1           cup       None   Nestle Chef Mate Hot Dog Chili Sauce
# 2           cup       None                      Red Ripe Tomatoes
# 3           cup       None                         Sweet peppers
# 4         fl oz       None                            Lemon juice
# ...         ...        ...                                    ...
# 445980     tbsp       None                                  Basil
# 445981      tsp       None                                 Garlic
# 445982     tbsp       None                            Fennel seed
# 445983      tsp       None                                   Salt
# 445984  serving       None                     Crushed Red Pepper
#
#        ingredient_addon_a ingredient_addon_b  norm_calories   norm_unit  \
# 0        no skin, roasted             cooked     286.792453      breast
# 1                    None               None     276.000000         cup
# 2                    None               None      38.000000         cup
# 3                    None               bell      39.393939         cup
# 4                    None               None       6.000000          oz
# ...                   ...                ...            ...         ...
# 445980               None               None      10.666667  tablespoon
# 445981               None               None       4.000000    teaspoon
# 445982               None               None      16.666667  tablespoon
# 445983               None               None       0.000000    teaspoon
# 445984               None               None       0.000000     serving
#
#                         norm_ingredient_name
# 0                             chicken breast
# 1       nestle chef mate hot dog chili sauce
# 2                          red ripe tomatoes
# 3                              sweet peppers
# 4                                lemon juice
# ...                                      ...
# 445980                                 basil
# 445981                                garlic
# 445982                           fennel seed
# 445983                                  salt
# 445984                    crushed red pepper
#
# [445985 rows x 12 columns]

# %%
df_ing_complete.to_csv("../../data/sparkrecipes_ingredients.csv", index=False)
