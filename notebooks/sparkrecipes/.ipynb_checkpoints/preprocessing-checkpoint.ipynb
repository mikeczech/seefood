# %%
import pandas as pd
import re
from tqdm.notebook import tqdm
from difflib import SequenceMatcher

pd.set_option('max_colwidth', 40)
pd.set_option('display.max_rows', 40)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("../data/sparkrecipes_complete_tmp.csv")

# %%
df.head()
# Out:
#                             title                                image_url  \
# 0  Caribbean Black Beans and Rice                                      NaN
# 1                 Minestrone Soup                                      NaN
# 2        20-Minute Chicken Creole  https://sparkpeo.hs.llnwd.net/e1/res...
# 3     Beef and Vegetable Stir-Fry                                      NaN
# 4          Italian Vegetable Bake  https://sparkpeo.hs.llnwd.net/e1/res...
#
#                                ingredients  \
# 0  |||1 lb. dry black beans|||7 cups wa...
# 1  |||1/4 cup olive oil |||1 clove garl...
# 2  nonstick cooking spray as needed|||4...
# 3  |||\n2 tablespoons dry red wine |||\...
# 4  |||1 can (28 oz.) whole tomatoes  ||...
#
#                                        url  \
# 0  https://recipes.sparkpeople.com/reci...
# 1  https://recipes.sparkpeople.com/reci...
# 2  https://recipes.sparkpeople.com/reci...
# 3  https://recipes.sparkpeople.com/reci...
# 4  https://recipes.sparkpeople.com/reci...
#
#                        ingredient_calories Calories Total Fat Saturated Fat  \
# 0  227 calories of Beans, black, (1 cup...    479.6     3.9 g         0.6 g
# 1  56 calories of Tomato Pasta, (0.40 c...    153.1     3.1 g         0.4 g
# 2  152 calories of Chicken Breast (cook...    269.3     6.3 g         1.9 g
# 3  100 calories of Beef, round steak, (...    245.5    10.2 g         1.5 g
# 4  8 calories of Canned Tomatoes, (0.25...     37.2     0.2 g         0.1 g
#
#   Polyunsaturated Fat Monounsaturated Fat  ...    Iron Magnesium Manganese  \
# 0               1.3 g               1.6 g  ...  32.9 %    36.8 %    81.8 %
# 1               0.6 g               1.7 g  ...  14.8 %    15.8 %    33.2 %
# 2               1.1 g               2.1 g  ...  15.7 %    17.6 %    19.6 %
# 3               2.3 g               5.3 g  ...  11.5 %     8.9 %    13.1 %
# 4               0.1 g               0.0 g  ...   4.0 %     8.3 %    21.9 %
#
#    Niacin Pantothenic Acid Phosphorus Riboflavin Selenium Thiamin    Zinc
# 0  16.9 %           11.1 %     32.9 %      8.2 %   20.5 %  47.2 %  18.9 %
# 1  17.1 %            8.2 %     12.7 %     13.7 %    7.6 %  17.5 %   7.3 %
# 2  78.2 %           15.1 %     33.0 %     13.9 %   33.3 %  16.8 %  12.0 %
# 3  22.1 %            6.9 %     21.8 %     16.2 %   25.3 %  11.0 %  16.7 %
# 4   4.6 %            2.2 %      4.5 %      3.8 %    1.2 %   6.6 %   2.4 %
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (54752, 36)

# %%
df.isnull().mean()
# Out:
# title                  0.000310
# image_url              0.957901
# ingredients            0.000858
# url                    0.000000
# ingredient_calories    0.000639
# Calories               0.000639
# Total Fat              0.000639
# Saturated Fat          0.000639
# Polyunsaturated Fat    0.000639
# Monounsaturated Fat    0.000639
# Cholesterol            0.000639
# Sodium                 0.000639
# Potassium              0.000639
# Total Carbohydrate     0.000639
# Dietary Fiber          0.000639
# Sugars                 0.000639
# Protein                0.000639
# Vitamin A              0.000639
# Vitamin B-12           0.000639
# Vitamin B-6            0.000639
# Vitamin C              0.000639
# Vitamin D              0.000639
# Vitamin E              0.000639
# Calcium                0.000639
# Copper                 0.000639
# Folate                 0.000639
# Iron                   0.000639
# Magnesium              0.000639
# Manganese              0.000639
# Niacin                 0.000639
# Pantothenic Acid       0.000639
# Phosphorus             0.000639
# Riboflavin             0.000639
# Selenium               0.000639
# Thiamin                0.000639
# Zinc                   0.000639
# dtype: float64

# %%
df = df[~df["Calories"].isnull()]

# %% [markdown]
# ## Preprocess Total Calories

# %%
df["total_calories"] = df["Calories"].apply(lambda x: float(x.replace(",", ""))) 
df = df[df.total_calories <= 1000]

# %%
df.head()
# Out:
#                             title                                image_url  \
# 0  Caribbean Black Beans and Rice                                      NaN
# 1                 Minestrone Soup                                      NaN
# 2        20-Minute Chicken Creole  https://sparkpeo.hs.llnwd.net/e1/res...
# 3     Beef and Vegetable Stir-Fry                                      NaN
# 4          Italian Vegetable Bake  https://sparkpeo.hs.llnwd.net/e1/res...
#
#                                ingredients  \
# 0  |||1 lb. dry black beans|||7 cups wa...
# 1  |||1/4 cup olive oil |||1 clove garl...
# 2  nonstick cooking spray as needed|||4...
# 3  |||\n2 tablespoons dry red wine |||\...
# 4  |||1 can (28 oz.) whole tomatoes  ||...
#
#                                        url  \
# 0  https://recipes.sparkpeople.com/reci...
# 1  https://recipes.sparkpeople.com/reci...
# 2  https://recipes.sparkpeople.com/reci...
# 3  https://recipes.sparkpeople.com/reci...
# 4  https://recipes.sparkpeople.com/reci...
#
#                        ingredient_calories Calories Total Fat Saturated Fat  \
# 0  227 calories of Beans, black, (1 cup...    479.6     3.9 g         0.6 g
# 1  56 calories of Tomato Pasta, (0.40 c...    153.1     3.1 g         0.4 g
# 2  152 calories of Chicken Breast (cook...    269.3     6.3 g         1.9 g
# 3  100 calories of Beef, round steak, (...    245.5    10.2 g         1.5 g
# 4  8 calories of Canned Tomatoes, (0.25...     37.2     0.2 g         0.1 g
#
#   Polyunsaturated Fat Monounsaturated Fat  ... Magnesium Manganese  Niacin  \
# 0               1.3 g               1.6 g  ...    36.8 %    81.8 %  16.9 %
# 1               0.6 g               1.7 g  ...    15.8 %    33.2 %  17.1 %
# 2               1.1 g               2.1 g  ...    17.6 %    19.6 %  78.2 %
# 3               2.3 g               5.3 g  ...     8.9 %    13.1 %  22.1 %
# 4               0.1 g               0.0 g  ...     8.3 %    21.9 %   4.6 %
#
#   Pantothenic Acid Phosphorus Riboflavin Selenium Thiamin    Zinc  \
# 0           11.1 %     32.9 %      8.2 %   20.5 %  47.2 %  18.9 %
# 1            8.2 %     12.7 %     13.7 %    7.6 %  17.5 %   7.3 %
# 2           15.1 %     33.0 %     13.9 %   33.3 %  16.8 %  12.0 %
# 3            6.9 %     21.8 %     16.2 %   25.3 %  11.0 %  16.7 %
# 4            2.2 %      4.5 %      3.8 %    1.2 %   6.6 %   2.4 %
#
#   total_calories
# 0          479.6
# 1          153.1
# 2          269.3
# 3          245.5
# 4           37.2
#
# [5 rows x 37 columns]

# %%
df_base = df[["title", "image_url", "total_calories", "url"]].reset_index()
df_base.head()
# Out:
#    index                           title  \
# 0      0  Caribbean Black Beans and Rice
# 1      1                 Minestrone Soup
# 2      2        20-Minute Chicken Creole
# 3      3     Beef and Vegetable Stir-Fry
# 4      4          Italian Vegetable Bake
#
#                                  image_url  total_calories  \
# 0                                      NaN           479.6
# 1                                      NaN           153.1
# 2  https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 3                                      NaN           245.5
# 4  https://sparkpeo.hs.llnwd.net/e1/res...            37.2
#
#                                        url
# 0  https://recipes.sparkpeople.com/reci...
# 1  https://recipes.sparkpeople.com/reci...
# 2  https://recipes.sparkpeople.com/reci...
# 3  https://recipes.sparkpeople.com/reci...
# 4  https://recipes.sparkpeople.com/reci...

# %%
df_base.columns = ["recipe_id", "title", "image_url", "total_calories", "url"]
df_base.head()
# Out:
#    recipe_id                           title  \
# 0          0  Caribbean Black Beans and Rice
# 1          1                 Minestrone Soup
# 2          2        20-Minute Chicken Creole
# 3          3     Beef and Vegetable Stir-Fry
# 4          4          Italian Vegetable Bake
#
#                                  image_url  total_calories  \
# 0                                      NaN           479.6
# 1                                      NaN           153.1
# 2  https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 3                                      NaN           245.5
# 4  https://sparkpeo.hs.llnwd.net/e1/res...            37.2
#
#                                        url
# 0  https://recipes.sparkpeople.com/reci...
# 1  https://recipes.sparkpeople.com/reci...
# 2  https://recipes.sparkpeople.com/reci...
# 3  https://recipes.sparkpeople.com/reci...
# 4  https://recipes.sparkpeople.com/reci...

# %%
df_base.total_calories.hist(bins=200, figsize=(10, 7))

# %%
df_base.describe()
# Out:
#           recipe_id  total_calories
# count  54068.000000    54068.000000
# mean   27410.566879      230.315608
# std    15792.770930      141.393810
# min        0.000000        0.000000
# 25%    13778.750000      128.500000
# 50%    27420.500000      205.400000
# 75%    41077.250000      304.500000
# max    54751.000000      999.900000

# %% [markdown]
# ## Preprocess Ingredients

# %%
df.ingredient_calories.values[0].split("|||")
# Out:
# ['227 calories of Beans, black, (1 cup)',
#  '205 calories of White Rice, long grain, cooked, (1 cup)',
#  '21 calories of Canola Oil, (0.17 tbsp)',
#  '15 calories of Onions, raw, (0.25 cup, chopped)',
#  '5 calories of Sweet peppers (bell), (0.17 medium (approx 2-3/4" long, 2-1/2" dia))',
#  '3 calories of Lemons, peeled, (0.17 fruit (2-1/8" dia))',
#  '1 calories of Garlic, (0.25 clove)',
#  '1 calories of Bay Leaf, (0.50 tsp, crumbled)',
#  '0 calories of Cider Vinegar, (0.17 tbsp)',
#  '0 calories of Pimentos, (0.75 slice)',
#  '0 calories of Salt, (0.10 tsp)']

# %%
df_ing_cal = pd.DataFrame(df.ingredient_calories.str.rsplit(r"|||").tolist()).stack().reset_index([0]).reset_index(drop=True)
df_ing_cal.columns = ["recipe_id", "ingredient"]
df_ing_cal
# Out:
#         recipe_id                               ingredient
# 0               0    227 calories of Beans, black, (1 cup)
# 1               0  205 calories of White Rice, long gra...
# 2               0   21 calories of Canola Oil, (0.17 tbsp)
# 3               0  15 calories of Onions, raw, (0.25 cu...
# 4               0  5 calories of Sweet peppers (bell), ...
# ...           ...                                      ...
# 378620      54066  1 calories of Rosemary, dried, (0.25...
# 378621      54067  110 calories of Tyson boneless, skin...
# 378622      54067  100 calories of Beans, black, (0.44 ...
# 378623      54067  58 calories of Yellow Sweet Corn, Ca...
# 378624      54067  17 calories of Old El Paso Taco Seas...
#
# [378625 rows x 2 columns]

# %%
df_ing_cal_fine = pd.DataFrame(df_ing_cal.ingredient.str.split("calories of").tolist(), index=df_ing_cal.index)
df_ing_cal_fine.columns = ["calories", "ingredient"]
df_ing_cal_fine = df_ing_cal_fine.join(df_ing_cal[["recipe_id"]])
df_ing_cal_fine
# Out:
#        calories                               ingredient  recipe_id
# 0          227                     Beans, black, (1 cup)          0
# 1          205    White Rice, long grain, cooked, (1 ...          0
# 2           21                   Canola Oil, (0.17 tbsp)          0
# 3           15          Onions, raw, (0.25 cup, chopped)          0
# 4            5    Sweet peppers (bell), (0.17 medium ...          0
# ...         ...                                      ...        ...
# 378620       1               Rosemary, dried, (0.25 tsp)      54066
# 378621     110    Tyson boneless, skinless chicken br...      54067
# 378622     100                  Beans, black, (0.44 cup)      54067
# 378623      58     Yellow Sweet Corn, Canned, (0.44 cup)      54067
# 378624      17    Old El Paso Taco Seasoning Mix (40%...      54067
#
# [378625 rows x 3 columns]

# %%
def extract_addon(input_str):
    open_bracket_ctr = 0
    inner_chars = []
    bracket_text = []
    for c in input_str:
        if c == "(":
            open_bracket_ctr += 1
            inner_chars.append("(")
        elif c == ")":
            open_bracket_ctr -= 1
            inner_chars.append(")")
            if open_bracket_ctr == 0:
                bracket_text.append(inner_chars)
                inner_chars = []
        elif open_bracket_ctr >= 1:
            inner_chars.append(c)
    result = ["".join(x).strip() for x in bracket_text]
    if len(result) > 0:
        return result[-1][1:-1]
    else:
        return None

# %%
extract_addon("balsamic vinegar, (0.08 tablespoon)")
# Out:
# '0.08 tablespoon'

# %%
extract_addon('Sweet peppers (bell), (0.17 medium (approx 2-3/4" long, 2-1/2" dia))')
# Out:
# '0.17 medium (approx 2-3/4" long, 2-1/2" dia)'

# %%
def extract_amount(ingredient):
    amount_p = extract_addon(ingredient)
    amount_p_addon = extract_addon(amount_p) if amount_p else None
    amount_pp = amount_p.replace(f"({amount_p_addon})", "") if amount_p else None
    amount_ppp = amount_pp.split(",")[0] if amount_pp else None
    
    if amount_ppp:
        match = re.search(r'([0-9]+(\.[0-9]+)?)\s(.*)', amount_ppp, re.IGNORECASE)
        if match:
            return match.group(1), match.group(3), amount_p_addon
    return amount_ppp, None, amount_p_addon

def process_ingredient(ingredient):
    ingredient_p = ingredient.replace(f"({extract_addon(ingredient)})", "")[:-2]
    ingredient_p_addon = extract_addon(ingredient_p)
    ingredient_pp = ingredient_p.replace(f"({ingredient_p_addon})", "") if ingredient else None
    ingredient_ppp = ingredient_pp.split(",")[0] if ingredient_pp else None
    ingredient_pp_addon =  ",".join(ingredient_pp.split(",")[1:])
    ingredient_pp_addon_p = None if ingredient_pp_addon == "" else ingredient_pp_addon
    return ingredient_ppp, ingredient_pp_addon_p, ingredient_p_addon

def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

# %%
df_fine_amount = pd.DataFrame(df_ing_cal_fine["ingredient"].map(lambda x: extract_amount(x)).tolist(), index=df_ing_cal_fine.index)
df_fine_amount.columns = ["amount", "unit", "unit_addon"]
df_fine_ingredient = pd.DataFrame(df_ing_cal_fine["ingredient"].map(lambda x: process_ingredient(x)).tolist(), index=df_ing_cal_fine.index)
df_fine_ingredient.columns = ["ingredient_name", "ingredient_addon_a", "ingredient_addon_b"]

# %%
df_ing_complete = df_ing_cal_fine[["recipe_id", "ingredient", "calories"]].join(df_fine_amount).join(df_fine_ingredient)
df_ing_complete["calories"] = df_ing_complete["calories"].str.replace(",", "").astype(float)
df_ing_complete["amount"] = df_ing_complete["amount"].map(lambda x: float(x) if x and isfloat(x) else None)

# %%
df_ing_complete
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 0               0                    Beans, black, (1 cup)     227.0    1.00
# 1               0   White Rice, long grain, cooked, (1 ...     205.0    1.00
# 2               0                  Canola Oil, (0.17 tbsp)      21.0    0.17
# 3               0         Onions, raw, (0.25 cup, chopped)      15.0    0.25
# 4               0   Sweet peppers (bell), (0.17 medium ...       5.0    0.17
# ...           ...                                      ...       ...     ...
# 378620      54066              Rosemary, dried, (0.25 tsp)       1.0    0.25
# 378621      54067   Tyson boneless, skinless chicken br...     110.0    4.00
# 378622      54067                 Beans, black, (0.44 cup)     100.0    0.44
# 378623      54067    Yellow Sweet Corn, Canned, (0.44 cup)      58.0    0.44
# 378624      54067   Old El Paso Taco Seasoning Mix (40%...      17.0    2.25
#
#            unit                      unit_addon  \
# 0           cup                            None
# 1           cup                            None
# 2          tbsp                            None
# 3           cup                            None
# 4       medium   approx 2-3/4" long, 2-1/2" dia
# ...         ...                             ...
# 378620      tsp                            None
# 378621       oz                            None
# 378622      cup                            None
# 378623      cup                            None
# 378624      tsp                            None
#
#                          ingredient_name        ingredient_addon_a  \
# 0                                  Beans                     black
# 1                             White Rice        long grain, cooked
# 2                             Canola Oil                      None
# 3                                 Onions                       raw
# 4                         Sweet peppers                       None
# ...                                  ...                       ...
# 378620                          Rosemary                     dried
# 378621                    Tyson boneless   skinless chicken breast
# 378622                             Beans                     black
# 378623                 Yellow Sweet Corn                    Canned
# 378624   Old El Paso Taco Seasoning Mix                       None
#
#        ingredient_addon_b
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    bell
# ...                   ...
# 378620               None
# 378621               None
# 378622               None
# 378623               None
# 378624    40% Less Sodium
#
# [378625 rows x 9 columns]

# %% [markdown]
# ### Analyze calories and amounts

# %%
df_ing_complete.dtypes
# Out:
# recipe_id               int64
# ingredient             object
# calories              float64
# amount                float64
# unit                   object
# unit_addon             object
# ingredient_name        object
# ingredient_addon_a     object
# ingredient_addon_b     object
# dtype: object

# %%
df_ing_complete[["calories", "amount"]].describe()
# Out:
#             calories         amount
# count  378625.000000  378518.000000
# mean       33.128644       2.590023
# std        58.075906     117.845043
# min         0.000000       0.000000
# 25%         2.000000       0.100000
# 50%        12.000000       0.250000
# 75%        40.000000       0.630000
# max     12000.000000   34811.000000

# %%
df_ing_complete[["calories", "amount"]].hist(bins=200, figsize=(20, 7), log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x138efca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1390b1898>]],
#       dtype=object)

# %%
df_ing_complete[df_ing_complete.calories < 1000][["calories", "amount"]].hist(bins=200, figsize=(20, 7), log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13ad2db00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aef1c88>]],
#       dtype=object)

# %%
df_ing_complete.isna().mean().plot.bar(log=True, figsize=(10, 7))

# %% [markdown]
# ### Normalize calories

# %%
df_ing_complete["norm_calories"] = df_ing_complete["calories"] /  df_ing_complete["amount"]

# %%
df_ing_complete["norm_calories"].hist(bins=100, log=True)

# %%
df_ing_complete[df_ing_complete.norm_calories > 1000]
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 13              1                    Olive Oil, (0.01 cup)      19.0    0.01
# 112            12                   Canola Oil, (0.02 cup)      39.0    0.02
# 140            16                   Canola Oil, (0.04 cup)      77.0    0.04
# 310            39                    Olive Oil, (0.01 cup)      19.0    0.01
# 328            42              Margarine, soft, (0.02 cup)      33.0    0.02
# ...           ...                                      ...       ...     ...
# 378234      54012   Peanut Butter, smooth style, with s...      61.0    0.04
# 378336      54026                     Corn Oil, (0.03 cup)      58.0    0.03
# 378418      54036   Peanut Butter, smooth style, with s...      61.0    0.04
# 378419      54036   Peanut Butter, chunk style, (0.03 cup)      44.0    0.03
# 378597      54061   Cake, german chocolate, (0.04 packa...      83.0    0.04
#
#             unit unit_addon ingredient_name        ingredient_addon_a  \
# 13           cup       None       Olive Oil                      None
# 112          cup       None      Canola Oil                      None
# 140          cup       None      Canola Oil                      None
# 310          cup       None       Olive Oil                      None
# 328          cup       None       Margarine                      soft
# ...          ...        ...             ...                       ...
# 378234       cup       None   Peanut Butter   smooth style, with salt
# 378336       cup       None        Corn Oil                      None
# 378418       cup       None   Peanut Butter   smooth style, with salt
# 378419       cup       None   Peanut Butter               chunk style
# 378597  package    18.25 oz            Cake          german chocolate
#
#        ingredient_addon_b  norm_calories
# 13                   None    1900.000000
# 112                  None    1950.000000
# 140                  None    1925.000000
# 310                  None    1900.000000
# 328                  None    1650.000000
# ...                   ...            ...
# 378234               None    1525.000000
# 378336               None    1933.333333
# 378418               None    1525.000000
# 378419               None    1466.666667
# 378597               None    2075.000000
#
# [5611 rows x 10 columns]

# %% [markdown]
# ### Normalize units

# %%
df_ing_complete["unit"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_complete['unit'].unique()
# Out:
# array(['cup', 'tbsp', 'medium ', 'fruit ', 'clove', 'tsp', 'slice',
#        'can ', 'sprigs', 'breast', 'fl oz', 'oz', 'cup slices', 'stalk',
#        'can', 'eggplant', 'medium', 'oz ', 'large', 'cup elbow shaped',
#        'fillet', 'cup kernels', 'cup diced', 'tbsp chopped',
#        'large whole ', 'large ', 'fruit without seeds', 'head', 'unit ',
#        'cup ', 'small', 'cherry', 'package  yields', '1tsp', 'glass ',
#        'lemon yields', 'grams', 'serving', None, 'small ', 'leaf',
#        'tsp or 1 packet', 'tsp unpacked', 'fruit without skin',
#        'patty (4 oz', 'tortilla ', 'tsp packed', 'lb', 'cup chips ',
#        'Italian tomato', 'dash', 'medium (2-3/4" dia) ', 'pack ', 'cube ',
#        'stick', 'package ', 'crust', 'scoop', 'cloves', 'medium whole ',
#        'pepper', 'lime yields', 'ear', 'Cup', 'teaspoon', 'ice cube ',
#        'fruit without skin and seeds', 'carrot ', 'leaves', 'sweetpotato',
#        'artichoke', 'slice ', 'inner leaf', 'square ', 'pita', 'muffin',
#        'unit', 'bunch', 'pear', 'prune', 'slices ', 'ounces',
#        'large (3-1/4" dia) ', 'cup sprigs', 'cup cherry tomatoes',
#        'beet ', 'potato ', 'tomato', 'jumbo', 'medium (2-1/2" dia) ',
#        'fruit', 'container', 'tsp chopped', 'cucumber ',
#        'cup pieces or chips', 'plum tomato', 'leek', 'watermelon balls',
#        'cup mini chips', 'Serving', 'tortilla', 'quart', 'can  yields',
#        'cup of miniature', 'extra large', 'cup small shells', 'half',
#        'slice crust not eaten', 'beans ', 'bulb', 'fruit without refuse',
#        'mushrooms', 'tbsp ', 'packet ', 'pint as purchased', 'wedge',
#        'roll', 'wrapper', 'gram', 'medium slices', 'sheet dough',
#        'leaf outer', 'ounce', 'serving ', 'thigh', 'tablespoon', 'fl. oz',
#        'tbs', 'slice or wedge', 'grape', 'pat ', 'spear', 'cup chips',
#        'cracker', 'wedge yields', 'serving 2 pops', 'small (2-1/2" dia) ',
#        'small box ', 'carrot', 'drumstick', 'piece', 'Tbspn',
#        'miniature box ', 'cup shelled ', 'berries', 'spear ',
#        'container ', 'cup pieces', 'strips', 'block', 'cracker ',
#        'can or bottle ', 'rings', 'cake', 'biscuit ', 'small (2" dia) ',
#        'bag ', 'parsnip ', 'mushroom', 'berry', 'pie shell ',
#        'raspberries', 'package', 'cubic inch', 'piece ', 'tube cake ',
#        'chop', 'packet', 'frankfurter', 'package yields', 'roll ',
#        'squash ', 'large (2-3/4" dia) ', 'chicken', 'peanut',
#        'extra large ', 'ring ', 'cookie', 'croissant', 'slices', 'wedge ',
#        'leaf inner', 'bar ', 'wedge or slice ', 'raisins',
#        'slice or ring  with liquid', 'anchovies', 'wafer', 'date',
#        'patty', 'beets ', 'Triscuit Bits', 'link', 'stalks',
#        'individual ', 'breakfast treat ', 'stick ', 'link ', 'melon',
#        'jigger 1.5 fl oz', 'unit 2 large or 5 small', 'apricot',
#        'muffin ', 'portion', 'ladyfinger', 'cube', 'almond', 'Serving ',
#        'cubes', 'strip', 'pouch', 'cup slices ', 'leg', 'portion ',
#        'Gherkin ', 'serving 1/2 cup', 'wing', 'floweret', 'extra small ',
#        'radish ', 'head ', 'waterchestnuts', 'cup shredded', 'cherry ',
#        'miniatures', 'melon ',
#        'large rectangular piece or 2 squares or 4 small rectangular pieces',
#        'can (29 oz) ', 'cup large chips',
#        'fruit 2-1/4" high x 2-1/2" dia', 'single stick',
#        'individual packet', 'small whole ', 'small Gherkin ',
#        'package yield', 'pieces', 'spear tip ', 'strip ', 'waffle',
#        'pods ', 'halves', 'bagel ', 'regular', 'crispbread',
#        'super colossal', 'lump ', 'roll (pan', 'g', 'biscuit',
#        'frankfurter ', 'tsp brownulated', 'shoot', 'cup spiral shaped',
#        'toast', 'bar', 'pomegranate ', 'fruit 3-3/8" high x 3" diameter',
#        'fruit yields', 'fluid ounce', 'bunch cooked', 'drink box ',
#        'package yield ', 'cup oyster crackers', 'cup whole kernels',
#        'biscuits ', 'serving 1 pop', 'plum with liquid', 'pad',
#        'sandwich', 'steak', 'oz with bone', 'jar', 'sheet', 'saltines',
#        'bird whole', 'sheets', 'envelope', 'sprout', 'recipe yield',
#        'flowerets', 'pizza ', 'bird', 'medium slice ', 'patty ',
#        'sausage ', 'anchovy', 'brownie ', 'each', 'cup sections', 'yam',
#        'root', 'oz. can = 4 servings', 'sardines', 'miniature ', 'matzo',
#        'fig', 'slice thin', 'snack size ', 'miniature', 'midget Gherkin ',
#        'pimiento', 'fl oz ', 'sausage',
#        'tsp or 500 mg = 1 svg; 1/4 tsp =1 tsp sugar', 'oz.',
#        'cookie  rolled cookie dough', 'nuts', 'cone', "Butterfinger BB's",
#        'shell', 'flower', 'mL', 'quail', 'sausages ',
#        'slice (4" dia x 1/8" thick) ', 'tart shell', 'slice (1 oz) ',
#        'egg', 'serving 28 pieces', 'bun', 'cup chopped or diced', 'crab',
#        'liver', 'oz cooked', 'gumdrops', 'melba round'], dtype=object)

# %%
f"Number of unique units: {df_ing_complete['unit'].unique().shape[0]}"
# Out:
# 'Number of unique units: 326'

# %%
df_ing_complete[df_ing_complete["unit"].isna()]
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 264            33   Baked Potato, with skin, (0.50 larg...     139.0     NaN
# 6269          844   Baked Potato, with skin, (1 large (...     278.0     NaN
# 10199        1446   Baked Potato, with skin, (1 large (...     278.0     NaN
# 15869        2331   Baked Potato, with skin, (1 large (...     278.0     NaN
# 15880        2332   Great Value Sugar Free Lemonade Nat...       0.0     NaN
# ...           ...                                      ...       ...     ...
# 357126      50997   Baked Potato, with skin, (0.50 larg...     139.0     NaN
# 358945      51254   Baked Potato, with skin, (0.50 larg...     139.0     NaN
# 359568      51340   Baked Potato, with skin, (0.25 larg...      69.0     NaN
# 361382      51619   Baked Potato, with skin, (0.50 larg...     139.0     NaN
# 376774      53806   Baked Potato, with skin, (0.13 larg...      36.0     NaN
#
#         unit unit_addon                          ingredient_name  \
# 264     None       None                             Baked Potato
# 6269    None       None                             Baked Potato
# 10199   None       None                             Baked Potato
# 15869   None       None                             Baked Potato
# 15880   None       None   Great Value Sugar Free Lemonade Nat...
# ...      ...        ...                                      ...
# 357126  None       None                             Baked Potato
# 358945  None       None                             Baked Potato
# 359568  None       None                             Baked Potato
# 361382  None       None                             Baked Potato
# 376774  None       None                             Baked Potato
#
#                              ingredient_addon_a ingredient_addon_b  \
# 264      with skin, (0.50 large (3" to 4-1/4...               None
# 6269      with skin, (1 large (3" to 4-1/4" dia               None
# 10199     with skin, (1 large (3" to 4-1/4" dia               None
# 15869     with skin, (1 large (3" to 4-1/4" dia               None
# 15880                                  (0.20 cu               None
# ...                                         ...                ...
# 357126   with skin, (0.50 large (3" to 4-1/4...               None
# 358945   with skin, (0.50 large (3" to 4-1/4...               None
# 359568   with skin, (0.25 large (3" to 4-1/4...               None
# 361382   with skin, (0.50 large (3" to 4-1/4...               None
# 376774   with skin, (0.13 large (3" to 4-1/4...               None
#
#         norm_calories
# 264               NaN
# 6269              NaN
# 10199             NaN
# 15869             NaN
# 15880             NaN
# ...               ...
# 357126            NaN
# 358945            NaN
# 359568            NaN
# 361382            NaN
# 376774            NaN
#
# [107 rows x 10 columns]

# %% [markdown]
# * lowercase vs. uppercase (x)
# * strip (x)
# * tbsp, tsp, tablespoon, tbs, Tbspn
# * cup X
# * tbsp X
# * 1tsp
# * None?
# * X or Y

# %%
MIN_UNIT_COUNT = 300

tablespoon_abbrev = ["tbsp", "tablespoon", "tbs"]
teaspoon_abbrev = ["tsp", "teaspoon"]
cup_abbrev = ["cup"]
oz_abbrev = ["oz", "fl oz"]

def norm_unit(abbrev, target, unit):
    if any([a in unit for a in abbrev]):
        return target
    else:
        return unit

# %%
df_ing_complete["norm_unit"] = (
    df_ing_complete["unit"]
    .str.strip()
    .str.lower()
    .map(lambda x: norm_unit(tablespoon_abbrev, "tablespoon", x) if x else None)
    .map(lambda x: norm_unit(teaspoon_abbrev, "teaspoon", x) if x else None)
    .map(lambda x: norm_unit(cup_abbrev, "cup", x) if x else None)
    .map(lambda x: norm_unit(oz_abbrev, "oz", x) if x else None)
)
unit_counts = df_ing_complete["norm_unit"].value_counts()
df_ing_complete["norm_unit"] = df_ing_complete["norm_unit"].map(lambda x: "generic_unit" if x and unit_counts[x] <= MIN_UNIT_COUNT else x)

# %%
f"Number of unique (normalized) units: {df_ing_complete['norm_unit'].unique().shape[0]}"
# Out:
# 'Number of unique (normalized) units: 44'

# %%
df_ing_complete["norm_unit"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_complete["norm_unit"].unique()
# Out:
# array(['cup', 'tablespoon', 'medium', 'fruit', 'clove', 'teaspoon',
#        'slice', 'can', 'generic_unit', 'breast', 'oz', 'stalk',
#        'eggplant', 'large', 'large whole', 'head', 'unit', 'small',
#        'package  yields', 'lemon yields', 'grams', 'serving', None,
#        'tortilla', 'lb', 'dash', 'medium (2-3/4" dia)', 'stick',
#        'package', 'cloves', 'medium whole', 'pepper', 'lime yields',
#        'fruit without skin and seeds', 'carrot', 'leaves', 'ounces',
#        'jumbo', 'plum tomato', 'can  yields', 'gram', 'medium slices',
#        'ounce', 'thigh'], dtype=object)

# %%
df_ing_complete["norm_unit"].value_counts()
# Out:
# cup            138155
# teaspoon        53316
# tablespoon      50683
# oz              26609
# serving         21317
#                 ...
# thigh             360
# plum tomato       354
# eggplant          352
# fruit             314
# carrot            304
# Name: norm_unit, Length: 43, dtype: int64

# %% [markdown]
# ### Normalize ingredient names

# %%
df_ing_complete["norm_ingredient_name"] = df_ing_complete["ingredient_name"].str.strip().str.lower()
df_ing_complete["norm_ingredient_name"]
# Out:
# 0                                  beans
# 1                             white rice
# 2                             canola oil
# 3                                 onions
# 4                          sweet peppers
#                        ...
# 378620                          rosemary
# 378621                    tyson boneless
# 378622                             beans
# 378623                 yellow sweet corn
# 378624    old el paso taco seasoning mix
# Name: norm_ingredient_name, Length: 378625, dtype: object

# %%
df_ing_complete["norm_ingredient_name"].unique().shape
# Out:
# (20296,)

# %%
df_ing_complete["norm_ingredient_name"].value_counts().nlargest(50).plot.bar(figsize=(15, 7))

# %%
df_ing_stats = df_ing_complete[["norm_ingredient_name", "calories"]].groupby(["norm_ingredient_name"]).agg(["mean", "sum", "std", "median"])
df_ing_stats
# Out:
#                                          calories
#                                              mean    sum        std median
# norm_ingredient_name
#                                               0.0    0.0   0.000000    0.0
# "better than boullion" chicken stock          4.5    9.0   4.949747    4.5
# "real lemon" lemon juice                      0.0    0.0        NaN    0.0
# "rowan hill bakery" wholemeal medium ...     44.0   44.0        NaN   44.0
# (1) lg. can pineapple tidbits                11.0   11.0        NaN   11.0
# ...                                           ...    ...        ...    ...
# zumo sausage                                480.0  480.0        NaN  480.0
# zylitol sweetener                             1.0    1.0        NaN    1.0
# zzdelete                                     67.0  134.0  94.752309   67.0
# ~lilydale frozen boneless skinless ch...     40.0   40.0        NaN   40.0
# 고추장 - hot pepper paste                        8.0    8.0        NaN    8.0
#
# [20296 rows x 4 columns]

# %%
with pd.option_context('display.max_rows', 100):
    df_ing_stats[df_ing_stats["calories", "mean"] <= 0.0]
# Out:
#                                   calories
#                                       mean  sum  std median
# norm_ingredient_name
#                                        0.0  0.0  0.0    0.0
# "real lemon" lemon juice               0.0  0.0  NaN    0.0
# **correction to recipe**               0.0  0.0  NaN    0.0
# *great value sf orange early rise      0.0  0.0  NaN    0.0
# *splenda                               0.0  0.0  NaN    0.0
# ...                                    ...  ...  ...    ...
# ziccinni                               0.0  0.0  NaN    0.0
# zuccini                                0.0  0.0  NaN    0.0
# zuchini                                0.0  0.0  0.0    0.0
# zuchinni                               0.0  0.0  0.0    0.0
# zuciini                                0.0  0.0  NaN    0.0
#
# [1461 rows x 4 columns]

# %%
df_ing_complete[df_ing_complete.norm_ingredient_name == "ground beef"]
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 117            13            Ground Beef (lean), (0.80 oz)      63.0    0.80
# 203            24               Ground Beef (lean), (2 oz)     157.0    2.00
# 212            25      Ground Beef (extra lean), (2.50 oz)     186.0    2.50
# 505            66                Ground beef, lean, (3 oz)     225.0    3.00
# 561            74             Ground beef, lean, (4.50 oz)     337.0    4.50
# ...           ...                                      ...       ...     ...
# 378141      54002                Ground beef, lean, (4 oz)     299.0    4.00
# 378256      54015   Ground beef, extra lean (15% fat) p...     292.0    4.00
# 378296      54020             Ground beef, lean, (1.33 oz)     100.0    1.33
# 378403      54035             Ground beef, lean, (1.20 oz)      90.0    1.20
# 378467      54041             Ground beef, lean, (0.38 oz)      28.0    0.38
#
#        unit unit_addon ingredient_name        ingredient_addon_a  \
# 117      oz       None    Ground Beef                       None
# 203      oz       None    Ground Beef                       None
# 212      oz       None    Ground Beef                       None
# 505      oz       None     Ground beef                      lean
# 561      oz       None     Ground beef                      lean
# ...     ...        ...             ...                       ...
# 378141   oz       None     Ground beef                      lean
# 378256   oz       None     Ground beef   extra lean  pan broiled
# 378296   oz       None     Ground beef                      lean
# 378403   oz       None     Ground beef                      lean
# 378467   oz       None     Ground beef                      lean
#
#        ingredient_addon_b  norm_calories norm_unit norm_ingredient_name
# 117                  lean      78.750000        oz          ground beef
# 203                  lean      78.500000        oz          ground beef
# 212            extra lean      74.400000        oz          ground beef
# 505                  None      75.000000        oz          ground beef
# 561                  None      74.888889        oz          ground beef
# ...                   ...            ...       ...                  ...
# 378141               None      74.750000        oz          ground beef
# 378256            15% fat      73.000000        oz          ground beef
# 378296               None      75.187970        oz          ground beef
# 378403               None      75.000000        oz          ground beef
# 378467               None      73.684211        oz          ground beef
#
# [2773 rows x 12 columns]

# %% [markdown]
# ### Analyze (approx.) duplicates in ingredient list (WIP)

# %% [raw]
# ingredients = df_ing_complete["norm_ingredient_name"].unique()

# %% [raw]
# ing_similarities = {}
# for i in tqdm(ingredients):
#     ing_similarities[i] = {}
#     for ii in ingredients:
#         ing_similarities[i][ii] = SequenceMatcher(None, i, ii).ratio()

# %% [raw]
# df_ing_similarities = pd.DataFrame(ing_similarities)
# df_ing_similarities.head()

# %% [raw]
# def get_most_similar(ingredient, ratio = 0.9):
#     mask = (df_ing_similarities.loc[ingredient] >= ratio) & (df_ing_similarities.loc[ingredient] != 1.0)
#     return df_ing_similarities.loc[ingredient][mask].index.values

# %% [raw]
# { i: get_most_similar(i) for i in ingredients[:20] if get_most_similar(i).shape[0] }

# %% [markdown]
# ### Analyze long ingredient names

# %%
df_ing_complete[["norm_ingredient_name", "calories"]][df_ing_complete.norm_ingredient_name.str.len() >= 30]["norm_ingredient_name"].unique().shape[0]
# Out:
# 8056

# %% [markdown]
# ### Persist dataframes for further analysis

# %%
df_base
# Out:
#        recipe_id                                   title  \
# 0              0          Caribbean Black Beans and Rice
# 1              1                         Minestrone Soup
# 2              2                20-Minute Chicken Creole
# 3              3             Beef and Vegetable Stir-Fry
# 4              4                  Italian Vegetable Bake
# ...          ...                                     ...
# 54063      54747             Slow Cooked Mexican Chicken
# 54064      54748  Classic Chocolate Truffle Souffle Cake
# 54065      54749                  Mexican Shrimp coctail
# 54066      54750                     Rosemary demi-glaze
# 54067      54751          Easy Mexican Chicken and Beans
#
#                                      image_url  total_calories  \
# 0                                          NaN           479.6
# 1                                          NaN           153.1
# 2      https://sparkpeo.hs.llnwd.net/e1/res...           269.3
# 3                                          NaN           245.5
# 4      https://sparkpeo.hs.llnwd.net/e1/res...            37.2
# ...                                        ...             ...
# 54063                                      NaN           178.1
# 54064  https://sparkpeo.hs.llnwd.net/e1/res...           364.5
# 54065                                      NaN            52.0
# 54066                                      NaN            80.9
# 54067                                      NaN           274.3
#
#                                            url
# 0      https://recipes.sparkpeople.com/reci...
# 1      https://recipes.sparkpeople.com/reci...
# 2      https://recipes.sparkpeople.com/reci...
# 3      https://recipes.sparkpeople.com/reci...
# 4      https://recipes.sparkpeople.com/reci...
# ...                                        ...
# 54063  https://recipes.sparkpeople.com/reci...
# 54064  https://recipes.sparkpeople.com/reci...
# 54065  https://recipes.sparkpeople.com/reci...
# 54066  https://recipes.sparkpeople.com/reci...
# 54067  https://recipes.sparkpeople.com/reci...
#
# [54068 rows x 5 columns]

# %%
df_base.to_csv("../data/sparkrecipes_base.csv", index=False)

# %%
df_ing_complete
# Out:
#         recipe_id                               ingredient  calories  amount  \
# 0               0                    Beans, black, (1 cup)     227.0    1.00
# 1               0   White Rice, long grain, cooked, (1 ...     205.0    1.00
# 2               0                  Canola Oil, (0.17 tbsp)      21.0    0.17
# 3               0         Onions, raw, (0.25 cup, chopped)      15.0    0.25
# 4               0   Sweet peppers (bell), (0.17 medium ...       5.0    0.17
# ...           ...                                      ...       ...     ...
# 378620      54066              Rosemary, dried, (0.25 tsp)       1.0    0.25
# 378621      54067   Tyson boneless, skinless chicken br...     110.0    4.00
# 378622      54067                 Beans, black, (0.44 cup)     100.0    0.44
# 378623      54067    Yellow Sweet Corn, Canned, (0.44 cup)      58.0    0.44
# 378624      54067   Old El Paso Taco Seasoning Mix (40%...      17.0    2.25
#
#            unit                      unit_addon  \
# 0           cup                            None
# 1           cup                            None
# 2          tbsp                            None
# 3           cup                            None
# 4       medium   approx 2-3/4" long, 2-1/2" dia
# ...         ...                             ...
# 378620      tsp                            None
# 378621       oz                            None
# 378622      cup                            None
# 378623      cup                            None
# 378624      tsp                            None
#
#                          ingredient_name        ingredient_addon_a  \
# 0                                  Beans                     black
# 1                             White Rice        long grain, cooked
# 2                             Canola Oil                      None
# 3                                 Onions                       raw
# 4                         Sweet peppers                       None
# ...                                  ...                       ...
# 378620                          Rosemary                     dried
# 378621                    Tyson boneless   skinless chicken breast
# 378622                             Beans                     black
# 378623                 Yellow Sweet Corn                    Canned
# 378624   Old El Paso Taco Seasoning Mix                       None
#
#        ingredient_addon_b  norm_calories   norm_unit  \
# 0                    None     227.000000         cup
# 1                    None     205.000000         cup
# 2                    None     123.529412  tablespoon
# 3                    None      60.000000         cup
# 4                    bell      29.411765      medium
# ...                   ...            ...         ...
# 378620               None       4.000000    teaspoon
# 378621               None      27.500000          oz
# 378622               None     227.272727         cup
# 378623               None     131.818182         cup
# 378624    40% Less Sodium       7.555556    teaspoon
#
#                   norm_ingredient_name
# 0                                beans
# 1                           white rice
# 2                           canola oil
# 3                               onions
# 4                        sweet peppers
# ...                                ...
# 378620                        rosemary
# 378621                  tyson boneless
# 378622                           beans
# 378623               yellow sweet corn
# 378624  old el paso taco seasoning mix
#
# [378625 rows x 12 columns]

# %%
df_ing_complete.to_csv("../data/sparkrecipes_ingredients.csv", index=False)
