# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import xgboost

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split

from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# %%
NUM_FEATURES = 512

def get_metrics(name, y_test, y_pred):
    return pd.DataFrame({
        "experiment_name": name,
        "r2_score": [r2_score(y_test, y_pred)],
        "explained_variance_score": [explained_variance_score(y_test, y_pred)],
        "max_error": [max_error(y_test, y_pred)],
        "mean_absolute_error": [mean_absolute_error(y_test, y_pred)],
        "mean_squared_error": [mean_squared_error(y_test, y_pred)],
        "median_absolute_error": [median_absolute_error(y_test, y_pred)]
    })

# %% [markdown]
# ## Load data

# %%
df_recipes = pd.read_csv("../../data/sparkrecipes_filtered.csv")
df_recipes
# Out:
#         recipe_id                                 title  total_calories  \
# 0              19               Turkey Stuffed Cabbage            155.5
# 1              25                   Easy Lemon Chicken            318.0
# 2              29                        Bavarian Beef            256.1
# 3              37               Garlic Mashed Potatoes            167.6
# 4              40           Wonderful Stuffed Potatoes            164.4
# ...           ...                                   ...             ...
# 446709    3199895    M4G's Loaded Split Pea & Ham Soup            164.4
# 446710    3199906              Vegetarian Skyline Chili           191.6
# 446711    3199939  2 FEV 17 Lemon cheese cake fat bomb            122.9
# 446712    3199943                           Lentil soup           117.8
# 446713    3199966                       THM Turtle Bars           301.1
#
#                                                       url  servings
# 0       https://recipes.sparkpeople.com/recipe-detail....      10.0
# 1       https://recipes.sparkpeople.com/recipe-detail....       4.0
# 2       https://recipes.sparkpeople.com/recipe-detail....       5.0
# 3       https://recipes.sparkpeople.com/recipe-detail....       4.0
# 4       https://recipes.sparkpeople.com/recipe-detail....       8.0
# ...                                                   ...       ...
# 446709  https://recipes.sparkpeople.com/recipe-detail....      16.0
# 446710  https://recipes.sparkpeople.com/recipe-detail....       4.0
# 446711  https://recipes.sparkpeople.com/recipe-detail....      14.0
# 446712  https://recipes.sparkpeople.com/recipe-detail....       6.0
# 446713  https://recipes.sparkpeople.com/recipe-detail....      16.0
#
# [446714 rows x 5 columns]

# %%
df_embeddings = pd.read_csv("../../data/sparkrecipes_embeddings.csv")
df_embeddings
# Out:
#         recipe_id       f_0       f_1       f_2       f_3       f_4       f_5  \
# 0          291788  1.657542  3.306842  0.150144  0.716325  1.412788  0.000000
# 1          186129  0.131091  0.756927  0.000000  0.000000  0.000000  0.042949
# 2           89647  0.256996  0.506713  0.000000  0.000000  0.295367  0.000000
# 3           63258  0.481375  0.975534  0.176997  0.003095  0.000000  0.389275
# 4          344852  0.872174  1.515256  6.107618  0.000000  0.000000  0.544032
# ...           ...       ...       ...       ...       ...       ...       ...
# 199995      15002  0.096497  0.538639  0.159070  1.035311  0.198755  0.254970
# 199996     174431  1.269787  3.974391  1.534365  0.107423  0.982815  0.000000
# 199997      59168  0.072812  2.873926  0.100634  0.573897  0.000000  0.023103
# 199998     144402  0.104968  0.239626  2.948921  1.556745  0.520375  1.501898
# 199999     201221  0.437993  1.234459  1.471211  0.497788  0.462741  0.000000
#
#              f_6       f_7       f_8  ...     f_502     f_503     f_504  \
# 0       0.612706  0.156094  1.111069  ...  0.851129  0.784485  0.000000
# 1       0.083060  0.087035  0.063373  ...  0.207664  0.217347  0.000000
# 2       2.670163  0.070306  0.785169  ...  0.104268  0.289502  1.122088
# 3       0.459856  0.805673  0.870744  ...  0.540625  1.119777  0.385062
# 4       0.224283  1.092227  5.745899  ...  2.801720  0.000000  0.204316
# ...          ...       ...       ...  ...       ...       ...       ...
# 199995  0.194375  0.614713  1.017653  ...  0.027319  0.812292  0.593234
# 199996  1.469487  0.050964  0.241303  ...  1.824443  0.025285  0.000000
# 199997  2.683917  0.042412  0.825761  ...  0.092382  0.000000  4.007784
# 199998  0.000000  0.237335  1.838255  ...  0.654853  0.171278  0.000000
# 199999  1.620586  0.202159  3.299002  ...  0.000000  0.000000  2.018790
#
#            f_505     f_506     f_507     f_508     f_509     f_510     f_511
# 0       0.000000  0.416459  0.553366  1.400850  0.046361  2.531902  0.652344
# 1       0.007426  0.236245  0.743847  4.196649  2.199195  0.461011  0.003973
# 2       0.000000  6.332223  0.903992  6.343424  0.200299  6.157534  3.011780
# 3       0.000000  3.115180  3.962124  5.996787  0.086081  4.714542  3.388931
# 4       0.000000  1.837780  0.611731  3.276474  0.122105  2.763169  1.290578
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  0.102146  3.986886  0.929327  2.781661  0.265407  6.964776  5.216623
# 199996  0.000000  1.270573  0.854426  2.218760  0.023541  1.541791  5.645164
# 199997  0.000000  0.525843  0.035090  0.373691  1.361642  0.266344  0.062209
# 199998  0.000000  2.507907  0.392842  0.200156  0.000000  0.095376  1.422864
# 199999  0.000000  6.909877  0.000000  0.528453  1.194617  5.744295  0.435839
#
# [200000 rows x 513 columns]

# %%
df = df_recipes.merge(df_embeddings, on="recipe_id", how="inner").reset_index(drop=True)
df
# Out:
#         recipe_id                                title  total_calories  \
# 0              19              Turkey Stuffed Cabbage            155.5
# 1              19              Turkey Stuffed Cabbage            155.5
# 2              19              Turkey Stuffed Cabbage            155.5
# 3              19              Turkey Stuffed Cabbage            155.5
# 4              19              Turkey Stuffed Cabbage            155.5
# ...           ...                                  ...             ...
# 151474     354226            Chicken and avocado salsa           276.2
# 151475     354226            Chicken and avocado salsa           276.2
# 151476     354228  Wild Rice & Chicken Stuffed Peppers           214.6
# 151477     354228  Wild Rice & Chicken Stuffed Peppers           214.6
# 151478     354234                          Easy Crepes            54.1
#
#                                                       url  servings       f_0  \
# 0       https://recipes.sparkpeople.com/recipe-detail....      10.0  0.039274
# 1       https://recipes.sparkpeople.com/recipe-detail....      10.0  0.210685
# 2       https://recipes.sparkpeople.com/recipe-detail....      10.0  0.000000
# 3       https://recipes.sparkpeople.com/recipe-detail....      10.0  0.065614
# 4       https://recipes.sparkpeople.com/recipe-detail....      10.0  0.000000
# ...                                                   ...       ...       ...
# 151474  https://recipes.sparkpeople.com/recipe-detail....       4.0  0.635687
# 151475  https://recipes.sparkpeople.com/recipe-detail....       4.0  0.909307
# 151476  https://recipes.sparkpeople.com/recipe-detail....       8.0  2.496334
# 151477  https://recipes.sparkpeople.com/recipe-detail....       8.0  0.007578
# 151478  https://recipes.sparkpeople.com/recipe-detail....       8.0  1.288271
#
# 1       0.197409  1.858713  0.629845  ...  0.073450  0.443867  0.291655
# 2       0.000000  0.025104  1.112276  ...  0.393245  1.779053  0.000000
# 3       0.119624  0.593723  0.117741  ...  1.971813  0.000000  0.027180
# 4       0.053632  1.659258  0.017005  ...  0.187800  0.734719  1.089992
# ...          ...       ...       ...  ...       ...       ...       ...
# 151474  0.260858  0.796501  0.795644  ...  0.485747  0.630409  1.478626
# 151475  0.233335  3.968189  1.412273  ...  0.317641  0.040940  3.500719
# 151476  0.721548  0.869754  0.183311  ...  1.880307  0.164251  1.573810
# 151477  0.364780  1.312318  0.000000  ...  0.949105  0.069891  0.323628
# 151478  0.000000  0.100439  0.711697  ...  3.587252  0.000000  0.311976
#
#            f_505     f_506     f_507     f_508     f_509     f_510     f_511
# 0       0.000000  5.123128  6.020833  6.416107  0.174369  4.878359  3.206631
# 1       0.000000  2.368726  0.000000  3.360098  0.259216  1.582883  0.000000
# 2       0.000000  2.339062  0.000000  1.480217  0.260992  4.061975  1.194522
# 3       0.000000  0.008362  2.783021  0.000000  0.685342  0.000000  0.010008
# 4       0.000000  8.540874  0.000000  4.588814  2.102819  0.095043  3.214623
# ...          ...       ...       ...       ...       ...       ...       ...
# 151474  0.013021  1.739062  1.111587  1.759785  0.037768  0.041654  0.249234
# 151475  0.000000  3.407953  0.117338  2.546248  1.015779  0.866630  0.210916
# 151476  0.362146  3.219645  1.253484  4.102161  0.218204  5.711287  1.963242
# 151477  0.149097  4.058978  9.484470  8.467857  2.107639  1.615626  2.498057
# 151478  0.000000  2.110820  0.630492  0.000000  1.413811  5.904784  0.945825
#
# [151479 rows x 512 columns]

# %%
y = df.total_calories
y
# Out:
# 0         155.5
# 1         155.5
# 2         155.5
# 3         155.5
# 4         155.5
#           ...
# 151474    276.2
# 151475    276.2
# 151476    214.6
# 151477    214.6
# 151478     54.1
# Name: total_calories, Length: 151479, dtype: float64

# %%
y.describe()
# Out:
# count    151479.000000
# mean        219.532315
# std         108.954159
# min          25.600000
# 25%         135.100000
# 50%         205.200000
# 75%         292.000000
# max         521.700000
# Name: total_calories, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Use XGBoost Regressor to predict total calories

# %%
model = xgboost.XGBRegressor(colsample_bytree=0.4,
                             gamma=1,                 
                             learning_rate=0.01,
                             max_depth=3,
                             n_estimators=1000,
                             objective='reg:squarederror',
                             reg_alpha=0.3,
                             subsample=0.8,
                             n_jobs=-1,
                             seed=42,
                             silent=True)

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]

# %%
# %time model.fit(X_train, y_train, eval_metric=["rmse", "mae"], eval_set=eval_set, verbose=False)
# Out:
# /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# CPU times: user 17min 33s, sys: 3.41 s, total: 17min 36s
# Wall time: 4min 54s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=1,
#              importance_type='gain', learning_rate=0.01, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0.3, reg_lambda=1, scale_pos_weight=1,
#              seed=42, silent=True, subsample=0.8, verbosity=1)

# %%
eval_results = pd.DataFrame(model.evals_result())
eval_results.columns = ["train", "test"]

# %%
def expand_results(eval_results):
    dfs = []
    cols = []
    for col in eval_results:
        for metric in eval_results.index:
            cols.append(f"{col}_{metric}")
            dfs.append(pd.DataFrame(eval_results[col][metric]))
    result = pd.concat(dfs, axis=1)
    result.columns = cols
    return result

# %%
df_eval_results = expand_results(eval_results)

# %%
df_eval_results.shape
# Out:
# (1000, 4)

# %%
df_eval_results.plot.line(figsize=(15, 11), loglog=True);
# Out:
# /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1085: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(left, right)

# %%
y_pred = model.predict(X_test)

# %%
df_xgboost_results = get_metrics("xgboost regressor", y_test, y_pred)
df_xgboost_results
# Out:
#      experiment_name  r2_score  explained_variance_score   max_error  \
# 0  xgboost regressor  0.112044                   0.11205  369.127698
#
#    mean_absolute_error  mean_squared_error  median_absolute_error
# 0            83.065105        10492.579519              72.476993

# %% [markdown]
# ## Use Linear Regression

# %%
lin_model = LinearRegression()

# %%
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_lin = lin_model.predict(X_test)

# %%
df_lin_results = get_metrics("linear regression", y_test, y_pred_lin)
df_lin_results
# Out:
#      experiment_name  r2_score  explained_variance_score   max_error  \
# 0  linear regression  0.108572                  0.108591  378.485083
#
#    mean_absolute_error  mean_squared_error  median_absolute_error
# 0            83.005282        10533.610153               72.37576

# %% [markdown]
# ## Baseline

# %%
from sklearn.base import BaseEstimator
from sklearn.base import RegressorMixin
from sklearn.utils.validation import check_is_fitted

class BaselineModel(BaseEstimator, RegressorMixin):

    def __init__(self):
        pass
    
    def fit(self, _, y):
        self.mean_ = y.mean()
        return self
    
    def predict(self, X):
        check_is_fitted(self, [])
        
        return np.array(X.shape[0] * [self.mean_])

# %%
baseline_model = BaselineModel()

# %%
baseline_model.fit(X_train, y_train)
# Out:
# BaselineModel()

# %%
y_pred_baseline = baseline_model.predict(X_test)

# %%
df_baseline_results = get_metrics("baseline", y_test, y_pred_baseline)
df_baseline_results
# Out:
#   experiment_name      r2_score  explained_variance_score   max_error  \
# 0        baseline -2.248232e-07                       0.0  302.050676
#
#    mean_absolute_error  mean_squared_error  median_absolute_error
# 0            89.078417         11816.55451              79.549324

# %% [markdown]
# ## Compare to Baseline

# %%
df_results = pd.concat([df_baseline_results, df_xgboost_results, df_lin_results]).reset_index(drop=True).T
df_results.columns = df_results.loc["experiment_name"].values
df_results = df_results.iloc[1:]

# %%
df_results
# Out:
#                              baseline xgboost regressor linear regression
# r2_score                 -2.24823e-07          0.112044          0.108572
# explained_variance_score            0           0.11205          0.108591
# max_error                     302.051           369.128           378.485
# mean_absolute_error           89.0784           83.0651           83.0053
# mean_squared_error            11816.6           10492.6           10533.6
# median_absolute_error         79.5493            72.477           72.3758

# %%
df_results.plot.bar(log=True, figsize=(12, 7));

# %% [markdown]
# ## Inspect predictions

# %% [raw]
# df_images = pd.read_csv("../../data/sparkrecipes_images.csv")
# df_images

# %%
ylim = (0,1200)

# %%
df.iloc[X_train.index].total_calories.plot.hist(bins=300, figsize=(16, 11), ylim=ylim);

# %%
df_predictions = df.iloc[X_test.index].assign(predicted_calories=y_pred) #.merge(df_images, on="recipe_id")

# %%
df_predictions[["total_calories", "predicted_calories"]].plot.hist(bins=300, figsize=(16, 11), alpha=.8, ylim=ylim);
