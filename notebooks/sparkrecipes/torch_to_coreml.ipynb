# %%
INPUT_MODEL_PATH = "../../models/calorie_regression_mobilenet.pt"
ONNX_MODEL_PATH = "../../models/calorie_regression_mobilenet.onnx"
COREML_MODEL_PATH = "../../models/calorie_regression_mobilenet.mlmodel"
IMAGE_SIZE = 224

# %% [markdown]
# ## Imports and Extensions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext lab_black

# %%
import sys

sys.path.insert(0, "../..")

# %%
import torch
from torchvision import models
from seefood.model import CalorieNet
from onnx_coreml import convert
import coremltools

# %% [markdown]
# ## Load Model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = torch.load(INPUT_MODEL_PATH).to(device)  ## TODO load state dict instead

# %% [markdown]
# ## Convert PyTorch to ONNX

# %%
dummy_input = torch.rand(1, 3, IMAGE_SIZE, IMAGE_SIZE).to(device)

# %%
input_names = ["image"]
output_names = ["calories"]

# %%
torch.onnx.export(
    model,
    dummy_input,
    ONNX_MODEL_PATH,
    verbose=True,
    input_names=input_names,
    output_names=output_names,
)
# Out:
# graph(%image : Float(1, 3, 224, 224),
#       %features.0.0.weight : Float(32, 3, 3, 3),
#       %features.0.1.weight : Float(32),
#       %features.0.1.bias : Float(32),
#       %features.0.1.running_mean : Float(32),
#       %features.0.1.running_var : Float(32),
#       %features.0.1.num_batches_tracked : Long(),
#       %features.1.conv.0.0.weight : Float(32, 1, 3, 3),
#       %features.1.conv.0.1.weight : Float(32),
#       %features.1.conv.0.1.bias : Float(32),
#       %features.1.conv.0.1.running_mean : Float(32),
#       %features.1.conv.0.1.running_var : Float(32),
#       %features.1.conv.0.1.num_batches_tracked : Long(),
#       %features.1.conv.1.weight : Float(16, 32, 1, 1),
#       %features.1.conv.2.weight : Float(16),
#       %features.1.conv.2.bias : Float(16),
#       %features.1.conv.2.running_mean : Float(16),
#       %features.1.conv.2.running_var : Float(16),
#       %features.1.conv.2.num_batches_tracked : Long(),
#       %features.2.conv.0.0.weight : Float(96, 16, 1, 1),
#       %features.2.conv.0.1.weight : Float(96),
#       %features.2.conv.0.1.bias : Float(96),
#       %features.2.conv.0.1.running_mean : Float(96),
#       %features.2.conv.0.1.running_var : Float(96),
#       %features.2.conv.0.1.num_batches_tracked : Long(),
#       %features.2.conv.1.0.weight : Float(96, 1, 3, 3),
#       %features.2.conv.1.1.weight : Float(96),
#       %features.2.conv.1.1.bias : Float(96),
#       %features.2.conv.1.1.running_mean : Float(96),
#       %features.2.conv.1.1.running_var : Float(96),
#       %features.2.conv.1.1.num_batches_tracked : Long(),
#       %features.2.conv.2.weight : Float(24, 96, 1, 1),
#       %features.2.conv.3.weight : Float(24),
#       %features.2.conv.3.bias : Float(24),
#       %features.2.conv.3.running_mean : Float(24),
#       %features.2.conv.3.running_var : Float(24),
#       %features.2.conv.3.num_batches_tracked : Long(),
#       %features.3.conv.0.0.weight : Float(144, 24, 1, 1),
#       %features.3.conv.0.1.weight : Float(144),
#       %features.3.conv.0.1.bias : Float(144),
#       %features.3.conv.0.1.running_mean : Float(144),
#       %features.3.conv.0.1.running_var : Float(144),
#       %features.3.conv.0.1.num_batches_tracked : Long(),
#       %features.3.conv.1.0.weight : Float(144, 1, 3, 3),
#       %features.3.conv.1.1.weight : Float(144),
#       %features.3.conv.1.1.bias : Float(144),
#       %features.3.conv.1.1.running_mean : Float(144),
#       %features.3.conv.1.1.running_var : Float(144),
#       %features.3.conv.1.1.num_batches_tracked : Long(),
#       %features.3.conv.2.weight : Float(24, 144, 1, 1),
#       %features.3.conv.3.weight : Float(24),
#       %features.3.conv.3.bias : Float(24),
#       %features.3.conv.3.running_mean : Float(24),
#       %features.3.conv.3.running_var : Float(24),
#       %features.3.conv.3.num_batches_tracked : Long(),
#       %features.4.conv.0.0.weight : Float(144, 24, 1, 1),
#       %features.4.conv.0.1.weight : Float(144),
#       %features.4.conv.0.1.bias : Float(144),
#       %features.4.conv.0.1.running_mean : Float(144),
#       %features.4.conv.0.1.running_var : Float(144),
#       %features.4.conv.0.1.num_batches_tracked : Long(),
#       %features.4.conv.1.0.weight : Float(144, 1, 3, 3),
#       %features.4.conv.1.1.weight : Float(144),
#       %features.4.conv.1.1.bias : Float(144),
#       %features.4.conv.1.1.running_mean : Float(144),
#       %features.4.conv.1.1.running_var : Float(144),
#       %features.4.conv.1.1.num_batches_tracked : Long(),
#       %features.4.conv.2.weight : Float(32, 144, 1, 1),
#       %features.4.conv.3.weight : Float(32),
#       %features.4.conv.3.bias : Float(32),
#       %features.4.conv.3.running_mean : Float(32),
#       %features.4.conv.3.running_var : Float(32),
#       %features.4.conv.3.num_batches_tracked : Long(),
#       %features.5.conv.0.0.weight : Float(192, 32, 1, 1),
#       %features.5.conv.0.1.weight : Float(192),
#       %features.5.conv.0.1.bias : Float(192),
#       %features.5.conv.0.1.running_mean : Float(192),
#       %features.5.conv.0.1.running_var : Float(192),
#       %features.5.conv.0.1.num_batches_tracked : Long(),
#       %features.5.conv.1.0.weight : Float(192, 1, 3, 3),
#       %features.5.conv.1.1.weight : Float(192),
#       %features.5.conv.1.1.bias : Float(192),
#       %features.5.conv.1.1.running_mean : Float(192),
#       %features.5.conv.1.1.running_var : Float(192),
#       %features.5.conv.1.1.num_batches_tracked : Long(),
#       %features.5.conv.2.weight : Float(32, 192, 1, 1),
#       %features.5.conv.3.weight : Float(32),
#       %features.5.conv.3.bias : Float(32),
#       %features.5.conv.3.running_mean : Float(32),
#       %features.5.conv.3.running_var : Float(32),
#       %features.5.conv.3.num_batches_tracked : Long(),
#       %features.6.conv.0.0.weight : Float(192, 32, 1, 1),
#       %features.6.conv.0.1.weight : Float(192),
#       %features.6.conv.0.1.bias : Float(192),
#       %features.6.conv.0.1.running_mean : Float(192),
#       %features.6.conv.0.1.running_var : Float(192),
#       %features.6.conv.0.1.num_batches_tracked : Long(),
#       %features.6.conv.1.0.weight : Float(192, 1, 3, 3),
#       %features.6.conv.1.1.weight : Float(192),
#       %features.6.conv.1.1.bias : Float(192),
#       %features.6.conv.1.1.running_mean : Float(192),
#       %features.6.conv.1.1.running_var : Float(192),
#       %features.6.conv.1.1.num_batches_tracked : Long(),
#       %features.6.conv.2.weight : Float(32, 192, 1, 1),
#       %features.6.conv.3.weight : Float(32),
#       %features.6.conv.3.bias : Float(32),
#       %features.6.conv.3.running_mean : Float(32),
#       %features.6.conv.3.running_var : Float(32),
#       %features.6.conv.3.num_batches_tracked : Long(),
#       %features.7.conv.0.0.weight : Float(192, 32, 1, 1),
#       %features.7.conv.0.1.weight : Float(192),
#       %features.7.conv.0.1.bias : Float(192),
#       %features.7.conv.0.1.running_mean : Float(192),
#       %features.7.conv.0.1.running_var : Float(192),
#       %features.7.conv.0.1.num_batches_tracked : Long(),
#       %features.7.conv.1.0.weight : Float(192, 1, 3, 3),
#       %features.7.conv.1.1.weight : Float(192),
#       %features.7.conv.1.1.bias : Float(192),
#       %features.7.conv.1.1.running_mean : Float(192),
#       %features.7.conv.1.1.running_var : Float(192),
#       %features.7.conv.1.1.num_batches_tracked : Long(),
#       %features.7.conv.2.weight : Float(64, 192, 1, 1),
#       %features.7.conv.3.weight : Float(64),
#       %features.7.conv.3.bias : Float(64),
#       %features.7.conv.3.running_mean : Float(64),
#       %features.7.conv.3.running_var : Float(64),
#       %features.7.conv.3.num_batches_tracked : Long(),
#       %features.8.conv.0.0.weight : Float(384, 64, 1, 1),
#       %features.8.conv.0.1.weight : Float(384),
#       %features.8.conv.0.1.bias : Float(384),
#       %features.8.conv.0.1.running_mean : Float(384),
#       %features.8.conv.0.1.running_var : Float(384),
#       %features.8.conv.0.1.num_batches_tracked : Long(),
#       %features.8.conv.1.0.weight : Float(384, 1, 3, 3),
#       %features.8.conv.1.1.weight : Float(384),
#       %features.8.conv.1.1.bias : Float(384),
#       %features.8.conv.1.1.running_mean : Float(384),
#       %features.8.conv.1.1.running_var : Float(384),
#       %features.8.conv.1.1.num_batches_tracked : Long(),
#       %features.8.conv.2.weight : Float(64, 384, 1, 1),
#       %features.8.conv.3.weight : Float(64),
#       %features.8.conv.3.bias : Float(64),
#       %features.8.conv.3.running_mean : Float(64),
#       %features.8.conv.3.running_var : Float(64),
#       %features.8.conv.3.num_batches_tracked : Long(),
#       %features.9.conv.0.0.weight : Float(384, 64, 1, 1),
#       %features.9.conv.0.1.weight : Float(384),
#       %features.9.conv.0.1.bias : Float(384),
#       %features.9.conv.0.1.running_mean : Float(384),
#       %features.9.conv.0.1.running_var : Float(384),
#       %features.9.conv.0.1.num_batches_tracked : Long(),
#       %features.9.conv.1.0.weight : Float(384, 1, 3, 3),
#       %features.9.conv.1.1.weight : Float(384),
#       %features.9.conv.1.1.bias : Float(384),
#       %features.9.conv.1.1.running_mean : Float(384),
#       %features.9.conv.1.1.running_var : Float(384),
#       %features.9.conv.1.1.num_batches_tracked : Long(),
#       %features.9.conv.2.weight : Float(64, 384, 1, 1),
#       %features.9.conv.3.weight : Float(64),
#       %features.9.conv.3.bias : Float(64),
#       %features.9.conv.3.running_mean : Float(64),
#       %features.9.conv.3.running_var : Float(64),
#       %features.9.conv.3.num_batches_tracked : Long(),
#       %features.10.conv.0.0.weight : Float(384, 64, 1, 1),
#       %features.10.conv.0.1.weight : Float(384),
#       %features.10.conv.0.1.bias : Float(384),
#       %features.10.conv.0.1.running_mean : Float(384),
#       %features.10.conv.0.1.running_var : Float(384),
#       %features.10.conv.0.1.num_batches_tracked : Long(),
#       %features.10.conv.1.0.weight : Float(384, 1, 3, 3),
#       %features.10.conv.1.1.weight : Float(384),
#       %features.10.conv.1.1.bias : Float(384),
#       %features.10.conv.1.1.running_mean : Float(384),
#       %features.10.conv.1.1.running_var : Float(384),
#       %features.10.conv.1.1.num_batches_tracked : Long(),
#       %features.10.conv.2.weight : Float(64, 384, 1, 1),
#       %features.10.conv.3.weight : Float(64),
#       %features.10.conv.3.bias : Float(64),
#       %features.10.conv.3.running_mean : Float(64),
#       %features.10.conv.3.running_var : Float(64),
#       %features.10.conv.3.num_batches_tracked : Long(),
#       %features.11.conv.0.0.weight : Float(384, 64, 1, 1),
#       %features.11.conv.0.1.weight : Float(384),
#       %features.11.conv.0.1.bias : Float(384),
#       %features.11.conv.0.1.running_mean : Float(384),
#       %features.11.conv.0.1.running_var : Float(384),
#       %features.11.conv.0.1.num_batches_tracked : Long(),
#       %features.11.conv.1.0.weight : Float(384, 1, 3, 3),
#       %features.11.conv.1.1.weight : Float(384),
#       %features.11.conv.1.1.bias : Float(384),
#       %features.11.conv.1.1.running_mean : Float(384),
#       %features.11.conv.1.1.running_var : Float(384),
#       %features.11.conv.1.1.num_batches_tracked : Long(),
#       %features.11.conv.2.weight : Float(96, 384, 1, 1),
#       %features.11.conv.3.weight : Float(96),
#       %features.11.conv.3.bias : Float(96),
#       %features.11.conv.3.running_mean : Float(96),
#       %features.11.conv.3.running_var : Float(96),
#       %features.11.conv.3.num_batches_tracked : Long(),
#       %features.12.conv.0.0.weight : Float(576, 96, 1, 1),
#       %features.12.conv.0.1.weight : Float(576),
#       %features.12.conv.0.1.bias : Float(576),
#       %features.12.conv.0.1.running_mean : Float(576),
#       %features.12.conv.0.1.running_var : Float(576),
#       %features.12.conv.0.1.num_batches_tracked : Long(),
#       %features.12.conv.1.0.weight : Float(576, 1, 3, 3),
#       %features.12.conv.1.1.weight : Float(576),
#       %features.12.conv.1.1.bias : Float(576),
#       %features.12.conv.1.1.running_mean : Float(576),
#       %features.12.conv.1.1.running_var : Float(576),
#       %features.12.conv.1.1.num_batches_tracked : Long(),
#       %features.12.conv.2.weight : Float(96, 576, 1, 1),
#       %features.12.conv.3.weight : Float(96),
#       %features.12.conv.3.bias : Float(96),
#       %features.12.conv.3.running_mean : Float(96),
#       %features.12.conv.3.running_var : Float(96),
#       %features.12.conv.3.num_batches_tracked : Long(),
#       %features.13.conv.0.0.weight : Float(576, 96, 1, 1),
#       %features.13.conv.0.1.weight : Float(576),
#       %features.13.conv.0.1.bias : Float(576),
#       %features.13.conv.0.1.running_mean : Float(576),
#       %features.13.conv.0.1.running_var : Float(576),
#       %features.13.conv.0.1.num_batches_tracked : Long(),
#       %features.13.conv.1.0.weight : Float(576, 1, 3, 3),
#       %features.13.conv.1.1.weight : Float(576),
#       %features.13.conv.1.1.bias : Float(576),
#       %features.13.conv.1.1.running_mean : Float(576),
#       %features.13.conv.1.1.running_var : Float(576),
#       %features.13.conv.1.1.num_batches_tracked : Long(),
#       %features.13.conv.2.weight : Float(96, 576, 1, 1),
#       %features.13.conv.3.weight : Float(96),
#       %features.13.conv.3.bias : Float(96),
#       %features.13.conv.3.running_mean : Float(96),
#       %features.13.conv.3.running_var : Float(96),
#       %features.13.conv.3.num_batches_tracked : Long(),
#       %features.14.conv.0.0.weight : Float(576, 96, 1, 1),
#       %features.14.conv.0.1.weight : Float(576),
#       %features.14.conv.0.1.bias : Float(576),
#       %features.14.conv.0.1.running_mean : Float(576),
#       %features.14.conv.0.1.running_var : Float(576),
#       %features.14.conv.0.1.num_batches_tracked : Long(),
#       %features.14.conv.1.0.weight : Float(576, 1, 3, 3),
#       %features.14.conv.1.1.weight : Float(576),
#       %features.14.conv.1.1.bias : Float(576),
#       %features.14.conv.1.1.running_mean : Float(576),
#       %features.14.conv.1.1.running_var : Float(576),
#       %features.14.conv.1.1.num_batches_tracked : Long(),
#       %features.14.conv.2.weight : Float(160, 576, 1, 1),
#       %features.14.conv.3.weight : Float(160),
#       %features.14.conv.3.bias : Float(160),
#       %features.14.conv.3.running_mean : Float(160),
#       %features.14.conv.3.running_var : Float(160),
#       %features.14.conv.3.num_batches_tracked : Long(),
#       %features.15.conv.0.0.weight : Float(960, 160, 1, 1),
#       %features.15.conv.0.1.weight : Float(960),
#       %features.15.conv.0.1.bias : Float(960),
#       %features.15.conv.0.1.running_mean : Float(960),
#       %features.15.conv.0.1.running_var : Float(960),
#       %features.15.conv.0.1.num_batches_tracked : Long(),
#       %features.15.conv.1.0.weight : Float(960, 1, 3, 3),
#       %features.15.conv.1.1.weight : Float(960),
#       %features.15.conv.1.1.bias : Float(960),
#       %features.15.conv.1.1.running_mean : Float(960),
#       %features.15.conv.1.1.running_var : Float(960),
#       %features.15.conv.1.1.num_batches_tracked : Long(),
#       %features.15.conv.2.weight : Float(160, 960, 1, 1),
#       %features.15.conv.3.weight : Float(160),
#       %features.15.conv.3.bias : Float(160),
#       %features.15.conv.3.running_mean : Float(160),
#       %features.15.conv.3.running_var : Float(160),
#       %features.15.conv.3.num_batches_tracked : Long(),
#       %features.16.conv.0.0.weight : Float(960, 160, 1, 1),
#       %features.16.conv.0.1.weight : Float(960),
#       %features.16.conv.0.1.bias : Float(960),
#       %features.16.conv.0.1.running_mean : Float(960),
#       %features.16.conv.0.1.running_var : Float(960),
#       %features.16.conv.0.1.num_batches_tracked : Long(),
#       %features.16.conv.1.0.weight : Float(960, 1, 3, 3),
#       %features.16.conv.1.1.weight : Float(960),
#       %features.16.conv.1.1.bias : Float(960),
#       %features.16.conv.1.1.running_mean : Float(960),
#       %features.16.conv.1.1.running_var : Float(960),
#       %features.16.conv.1.1.num_batches_tracked : Long(),
#       %features.16.conv.2.weight : Float(160, 960, 1, 1),
#       %features.16.conv.3.weight : Float(160),
#       %features.16.conv.3.bias : Float(160),
#       %features.16.conv.3.running_mean : Float(160),
#       %features.16.conv.3.running_var : Float(160),
#       %features.16.conv.3.num_batches_tracked : Long(),
#       %features.17.conv.0.0.weight : Float(960, 160, 1, 1),
#       %features.17.conv.0.1.weight : Float(960),
#       %features.17.conv.0.1.bias : Float(960),
#       %features.17.conv.0.1.running_mean : Float(960),
#       %features.17.conv.0.1.running_var : Float(960),
#       %features.17.conv.0.1.num_batches_tracked : Long(),
#       %features.17.conv.1.0.weight : Float(960, 1, 3, 3),
#       %features.17.conv.1.1.weight : Float(960),
#       %features.17.conv.1.1.bias : Float(960),
#       %features.17.conv.1.1.running_mean : Float(960),
#       %features.17.conv.1.1.running_var : Float(960),
#       %features.17.conv.1.1.num_batches_tracked : Long(),
#       %features.17.conv.2.weight : Float(320, 960, 1, 1),
#       %features.17.conv.3.weight : Float(320),
#       %features.17.conv.3.bias : Float(320),
#       %features.17.conv.3.running_mean : Float(320),
#       %features.17.conv.3.running_var : Float(320),
#       %features.17.conv.3.num_batches_tracked : Long(),
#       %features.18.0.weight : Float(1280, 320, 1, 1),
#       %features.18.1.weight : Float(1280),
#       %features.18.1.bias : Float(1280),
#       %features.18.1.running_mean : Float(1280),
#       %features.18.1.running_var : Float(1280),
#       %features.18.1.num_batches_tracked : Long(),
#       %regressor.1.weight : Float(512, 1280),
#       %regressor.1.bias : Float(512),
#       %regressor.2.weight : Float(1, 512),
#       %regressor.2.bias : Float(1)):
#   %317 : Float(1, 32, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%image, %features.0.0.weight), scope: CalorieNet/Sequential[features]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %318 : Float(1, 32, 112, 112) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%317, %features.0.1.weight, %features.0.1.bias, %features.0.1.running_mean, %features.0.1.running_var), scope: CalorieNet/Sequential[features]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %319 : Float(1, 32, 112, 112) = onnx::Clip[max=6, min=0](%318), scope: CalorieNet/Sequential[features]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %320 : Float(1, 32, 112, 112) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%319, %features.1.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[1]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %321 : Float(1, 32, 112, 112) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%320, %features.1.conv.0.1.weight, %features.1.conv.0.1.bias, %features.1.conv.0.1.running_mean, %features.1.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[1]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %322 : Float(1, 32, 112, 112) = onnx::Clip[max=6, min=0](%321), scope: CalorieNet/Sequential[features]/InvertedResidual[1]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %323 : Float(1, 16, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%322, %features.1.conv.1.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[1]/Sequential[conv]/Conv2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %324 : Float(1, 16, 112, 112) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%323, %features.1.conv.2.weight, %features.1.conv.2.bias, %features.1.conv.2.running_mean, %features.1.conv.2.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[1]/Sequential[conv]/BatchNorm2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %325 : Float(1, 96, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%324, %features.2.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %326 : Float(1, 96, 112, 112) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%325, %features.2.conv.0.1.weight, %features.2.conv.0.1.bias, %features.2.conv.0.1.running_mean, %features.2.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %327 : Float(1, 96, 112, 112) = onnx::Clip[max=6, min=0](%326), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %328 : Float(1, 96, 56, 56) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%327, %features.2.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %329 : Float(1, 96, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%328, %features.2.conv.1.1.weight, %features.2.conv.1.1.bias, %features.2.conv.1.1.running_mean, %features.2.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %330 : Float(1, 96, 56, 56) = onnx::Clip[max=6, min=0](%329), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %331 : Float(1, 24, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%330, %features.2.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %332 : Float(1, 24, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%331, %features.2.conv.3.weight, %features.2.conv.3.bias, %features.2.conv.3.running_mean, %features.2.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[2]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %333 : Float(1, 144, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%332, %features.3.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %334 : Float(1, 144, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%333, %features.3.conv.0.1.weight, %features.3.conv.0.1.bias, %features.3.conv.0.1.running_mean, %features.3.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %335 : Float(1, 144, 56, 56) = onnx::Clip[max=6, min=0](%334), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %336 : Float(1, 144, 56, 56) = onnx::Conv[dilations=[1, 1], group=144, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%335, %features.3.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %337 : Float(1, 144, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%336, %features.3.conv.1.1.weight, %features.3.conv.1.1.bias, %features.3.conv.1.1.running_mean, %features.3.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %338 : Float(1, 144, 56, 56) = onnx::Clip[max=6, min=0](%337), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %339 : Float(1, 24, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%338, %features.3.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %340 : Float(1, 24, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%339, %features.3.conv.3.weight, %features.3.conv.3.bias, %features.3.conv.3.running_mean, %features.3.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[3]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %341 : Float(1, 24, 56, 56) = onnx::Add(%332, %340), scope: CalorieNet/Sequential[features]/InvertedResidual[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %342 : Float(1, 144, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%341, %features.4.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %343 : Float(1, 144, 56, 56) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%342, %features.4.conv.0.1.weight, %features.4.conv.0.1.bias, %features.4.conv.0.1.running_mean, %features.4.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %344 : Float(1, 144, 56, 56) = onnx::Clip[max=6, min=0](%343), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %345 : Float(1, 144, 28, 28) = onnx::Conv[dilations=[1, 1], group=144, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%344, %features.4.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %346 : Float(1, 144, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%345, %features.4.conv.1.1.weight, %features.4.conv.1.1.bias, %features.4.conv.1.1.running_mean, %features.4.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %347 : Float(1, 144, 28, 28) = onnx::Clip[max=6, min=0](%346), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %348 : Float(1, 32, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%347, %features.4.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %349 : Float(1, 32, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%348, %features.4.conv.3.weight, %features.4.conv.3.bias, %features.4.conv.3.running_mean, %features.4.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[4]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %350 : Float(1, 192, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%349, %features.5.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %351 : Float(1, 192, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%350, %features.5.conv.0.1.weight, %features.5.conv.0.1.bias, %features.5.conv.0.1.running_mean, %features.5.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %352 : Float(1, 192, 28, 28) = onnx::Clip[max=6, min=0](%351), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %353 : Float(1, 192, 28, 28) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%352, %features.5.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %354 : Float(1, 192, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%353, %features.5.conv.1.1.weight, %features.5.conv.1.1.bias, %features.5.conv.1.1.running_mean, %features.5.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %355 : Float(1, 192, 28, 28) = onnx::Clip[max=6, min=0](%354), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %356 : Float(1, 32, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%355, %features.5.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %357 : Float(1, 32, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%356, %features.5.conv.3.weight, %features.5.conv.3.bias, %features.5.conv.3.running_mean, %features.5.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[5]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %358 : Float(1, 32, 28, 28) = onnx::Add(%349, %357), scope: CalorieNet/Sequential[features]/InvertedResidual[5] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %359 : Float(1, 192, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%358, %features.6.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %360 : Float(1, 192, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%359, %features.6.conv.0.1.weight, %features.6.conv.0.1.bias, %features.6.conv.0.1.running_mean, %features.6.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %361 : Float(1, 192, 28, 28) = onnx::Clip[max=6, min=0](%360), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %362 : Float(1, 192, 28, 28) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%361, %features.6.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %363 : Float(1, 192, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%362, %features.6.conv.1.1.weight, %features.6.conv.1.1.bias, %features.6.conv.1.1.running_mean, %features.6.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %364 : Float(1, 192, 28, 28) = onnx::Clip[max=6, min=0](%363), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %365 : Float(1, 32, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%364, %features.6.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %366 : Float(1, 32, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%365, %features.6.conv.3.weight, %features.6.conv.3.bias, %features.6.conv.3.running_mean, %features.6.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[6]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %367 : Float(1, 32, 28, 28) = onnx::Add(%358, %366), scope: CalorieNet/Sequential[features]/InvertedResidual[6] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %368 : Float(1, 192, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%367, %features.7.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %369 : Float(1, 192, 28, 28) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%368, %features.7.conv.0.1.weight, %features.7.conv.0.1.bias, %features.7.conv.0.1.running_mean, %features.7.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %370 : Float(1, 192, 28, 28) = onnx::Clip[max=6, min=0](%369), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %371 : Float(1, 192, 14, 14) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%370, %features.7.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %372 : Float(1, 192, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%371, %features.7.conv.1.1.weight, %features.7.conv.1.1.bias, %features.7.conv.1.1.running_mean, %features.7.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %373 : Float(1, 192, 14, 14) = onnx::Clip[max=6, min=0](%372), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %374 : Float(1, 64, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%373, %features.7.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %375 : Float(1, 64, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%374, %features.7.conv.3.weight, %features.7.conv.3.bias, %features.7.conv.3.running_mean, %features.7.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[7]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %376 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%375, %features.8.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %377 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%376, %features.8.conv.0.1.weight, %features.8.conv.0.1.bias, %features.8.conv.0.1.running_mean, %features.8.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %378 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%377), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %379 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%378, %features.8.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %380 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%379, %features.8.conv.1.1.weight, %features.8.conv.1.1.bias, %features.8.conv.1.1.running_mean, %features.8.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %381 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%380), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %382 : Float(1, 64, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%381, %features.8.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %383 : Float(1, 64, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%382, %features.8.conv.3.weight, %features.8.conv.3.bias, %features.8.conv.3.running_mean, %features.8.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[8]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %384 : Float(1, 64, 14, 14) = onnx::Add(%375, %383), scope: CalorieNet/Sequential[features]/InvertedResidual[8] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %385 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%384, %features.9.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %386 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%385, %features.9.conv.0.1.weight, %features.9.conv.0.1.bias, %features.9.conv.0.1.running_mean, %features.9.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %387 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%386), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %388 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%387, %features.9.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %389 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%388, %features.9.conv.1.1.weight, %features.9.conv.1.1.bias, %features.9.conv.1.1.running_mean, %features.9.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %390 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%389), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %391 : Float(1, 64, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%390, %features.9.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %392 : Float(1, 64, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%391, %features.9.conv.3.weight, %features.9.conv.3.bias, %features.9.conv.3.running_mean, %features.9.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[9]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %393 : Float(1, 64, 14, 14) = onnx::Add(%384, %392), scope: CalorieNet/Sequential[features]/InvertedResidual[9] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %394 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%393, %features.10.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %395 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%394, %features.10.conv.0.1.weight, %features.10.conv.0.1.bias, %features.10.conv.0.1.running_mean, %features.10.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %396 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%395), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %397 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%396, %features.10.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %398 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%397, %features.10.conv.1.1.weight, %features.10.conv.1.1.bias, %features.10.conv.1.1.running_mean, %features.10.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %399 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%398), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %400 : Float(1, 64, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%399, %features.10.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %401 : Float(1, 64, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%400, %features.10.conv.3.weight, %features.10.conv.3.bias, %features.10.conv.3.running_mean, %features.10.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[10]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %402 : Float(1, 64, 14, 14) = onnx::Add(%393, %401), scope: CalorieNet/Sequential[features]/InvertedResidual[10] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %403 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%402, %features.11.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %404 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%403, %features.11.conv.0.1.weight, %features.11.conv.0.1.bias, %features.11.conv.0.1.running_mean, %features.11.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %405 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%404), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %406 : Float(1, 384, 14, 14) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%405, %features.11.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %407 : Float(1, 384, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%406, %features.11.conv.1.1.weight, %features.11.conv.1.1.bias, %features.11.conv.1.1.running_mean, %features.11.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %408 : Float(1, 384, 14, 14) = onnx::Clip[max=6, min=0](%407), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %409 : Float(1, 96, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%408, %features.11.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[11]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
# ...
#   %421 : Float(1, 576, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%420, %features.13.conv.0.1.weight, %features.13.conv.0.1.bias, %features.13.conv.0.1.running_mean, %features.13.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %422 : Float(1, 576, 14, 14) = onnx::Clip[max=6, min=0](%421), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %423 : Float(1, 576, 14, 14) = onnx::Conv[dilations=[1, 1], group=576, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%422, %features.13.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %424 : Float(1, 576, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%423, %features.13.conv.1.1.weight, %features.13.conv.1.1.bias, %features.13.conv.1.1.running_mean, %features.13.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %425 : Float(1, 576, 14, 14) = onnx::Clip[max=6, min=0](%424), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %426 : Float(1, 96, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%425, %features.13.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %427 : Float(1, 96, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%426, %features.13.conv.3.weight, %features.13.conv.3.bias, %features.13.conv.3.running_mean, %features.13.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[13]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %428 : Float(1, 96, 14, 14) = onnx::Add(%419, %427), scope: CalorieNet/Sequential[features]/InvertedResidual[13] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %429 : Float(1, 576, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%428, %features.14.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %430 : Float(1, 576, 14, 14) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%429, %features.14.conv.0.1.weight, %features.14.conv.0.1.bias, %features.14.conv.0.1.running_mean, %features.14.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %431 : Float(1, 576, 14, 14) = onnx::Clip[max=6, min=0](%430), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %432 : Float(1, 576, 7, 7) = onnx::Conv[dilations=[1, 1], group=576, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%431, %features.14.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %433 : Float(1, 576, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%432, %features.14.conv.1.1.weight, %features.14.conv.1.1.bias, %features.14.conv.1.1.running_mean, %features.14.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %434 : Float(1, 576, 7, 7) = onnx::Clip[max=6, min=0](%433), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %435 : Float(1, 160, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%434, %features.14.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %436 : Float(1, 160, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%435, %features.14.conv.3.weight, %features.14.conv.3.bias, %features.14.conv.3.running_mean, %features.14.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[14]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %437 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%436, %features.15.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %438 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%437, %features.15.conv.0.1.weight, %features.15.conv.0.1.bias, %features.15.conv.0.1.running_mean, %features.15.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %439 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%438), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %440 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=960, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%439, %features.15.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %441 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%440, %features.15.conv.1.1.weight, %features.15.conv.1.1.bias, %features.15.conv.1.1.running_mean, %features.15.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %442 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%441), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %443 : Float(1, 160, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%442, %features.15.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %444 : Float(1, 160, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%443, %features.15.conv.3.weight, %features.15.conv.3.bias, %features.15.conv.3.running_mean, %features.15.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[15]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %445 : Float(1, 160, 7, 7) = onnx::Add(%436, %444), scope: CalorieNet/Sequential[features]/InvertedResidual[15] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %446 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%445, %features.16.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %447 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%446, %features.16.conv.0.1.weight, %features.16.conv.0.1.bias, %features.16.conv.0.1.running_mean, %features.16.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %448 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%447), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %449 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=960, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%448, %features.16.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %450 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%449, %features.16.conv.1.1.weight, %features.16.conv.1.1.bias, %features.16.conv.1.1.running_mean, %features.16.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %451 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%450), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %452 : Float(1, 160, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%451, %features.16.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %453 : Float(1, 160, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%452, %features.16.conv.3.weight, %features.16.conv.3.bias, %features.16.conv.3.running_mean, %features.16.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[16]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %454 : Float(1, 160, 7, 7) = onnx::Add(%445, %453), scope: CalorieNet/Sequential[features]/InvertedResidual[16] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torchvision/models/mobilenet.py:67:0
#   %455 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%454, %features.17.conv.0.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[0]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %456 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%455, %features.17.conv.0.1.weight, %features.17.conv.0.1.bias, %features.17.conv.0.1.running_mean, %features.17.conv.0.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[0]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %457 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%456), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[0]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %458 : Float(1, 960, 7, 7) = onnx::Conv[dilations=[1, 1], group=960, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%457, %features.17.conv.1.0.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[1]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %459 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%458, %features.17.conv.1.1.weight, %features.17.conv.1.1.bias, %features.17.conv.1.1.running_mean, %features.17.conv.1.1.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[1]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %460 : Float(1, 960, 7, 7) = onnx::Clip[max=6, min=0](%459), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/ConvBNReLU[1]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %461 : Float(1, 320, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%460, %features.17.conv.2.weight), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/Conv2d[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %462 : Float(1, 320, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%461, %features.17.conv.3.weight, %features.17.conv.3.bias, %features.17.conv.3.running_mean, %features.17.conv.3.running_var), scope: CalorieNet/Sequential[features]/InvertedResidual[17]/Sequential[conv]/BatchNorm2d[3] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %463 : Float(1, 1280, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%462, %features.18.0.weight), scope: CalorieNet/Sequential[features]/ConvBNReLU[18]/Conv2d[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %464 : Float(1, 1280, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%463, %features.18.1.weight, %features.18.1.bias, %features.18.1.running_mean, %features.18.1.running_var), scope: CalorieNet/Sequential[features]/ConvBNReLU[18]/BatchNorm2d[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %465 : Float(1, 1280, 7, 7) = onnx::Clip[max=6, min=0](%464), scope: CalorieNet/Sequential[features]/ConvBNReLU[18]/ReLU6[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:958:0
#   %466 : Float(1, 1280) = onnx::ReduceMean[axes=[2, 3], keepdims=0](%465), scope: CalorieNet/Sequential[regressor]/Dropout[0] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:807:0
#   %467 : Float(1, 512) = onnx::Gemm[alpha=1, beta=1, transB=1](%466, %regressor.1.weight, %regressor.1.bias), scope: CalorieNet/Sequential[regressor]/Linear[1] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1370:0
#   %468 : Float(1, 1) = onnx::Gemm[alpha=1, beta=1, transB=1](%467, %regressor.2.weight, %regressor.2.bias), scope: CalorieNet/Sequential[regressor]/Linear[2] # /home/mike/.conda/envs/seefood/lib/python3.7/site-packages/torch/nn/functional.py:1370:0
#   %calories : Float() = onnx::Squeeze[axes=[0, 1]](%468), scope: CalorieNet # ../../seefood/model.py:21:0
#   return (%calories)

# %% [markdown]
# ## Convert ONNX to CoreML

# %%
core_mlmodel = convert(model=ONNX_MODEL_PATH, image_input_names=["image"])

# %%
core_mlmodel.save(COREML_MODEL_PATH)

# %% [markdown]
# ## Model Evaluation

# %%
eval_model = coremltools.models.MLModel(COREML_MODEL_PATH)

# %%
eval_model
# Out:
# input {
#   name: "image"
#   type {
#     imageType {
#       width: 224
#       height: 224
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "calories"
#   type {
#     multiArrayType {
#       dataType: FLOAT32
#     }
#   }
# }
# metadata {
#   userDefined {
#     key: "coremltoolsVersion"
#     value: "3.3"
#   }
# }

# %%
eval_model.visualize_spec()
