# %%
import pandas as pd

import torch
import torch.nn as nn
from torchvision import datasets, models, transforms
from PIL import Image
from tqdm.notebook import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Load data

# %%
df_base = pd.read_csv("../../data/sparkrecipes_base.csv")
df_images = pd.read_csv("../../data/sparkrecipes_images.csv")

# %%
df = df_base.merge(df_images, on="recipe_id", how="inner").drop(["image_url"], axis=1)

# %%
df
# Out:
#    recipe_id                           title  total_calories  \
# 0          0  Caribbean Black Beans and Rice           479.6
# 1          1                 Minestrone Soup           153.1
# 2          2        20-Minute Chicken Creole           269.3
# 3          3     Beef and Vegetable Stir-Fry           245.5
# 4          4          Italian Vegetable Bake            37.2
#
#                                                  url  \
# 0  https://recipes.sparkpeople.com/recipe-detail....
# 1  https://recipes.sparkpeople.com/recipe-detail....
# 2  https://recipes.sparkpeople.com/recipe-detail....
# 3  https://recipes.sparkpeople.com/recipe-detail....
# 4  https://recipes.sparkpeople.com/recipe-detail....
#
#                       image_1                     image_2  \
# 0  ../../data/images/0/000001  ../../data/images/0/000002
# 1  ../../data/images/1/000001  ../../data/images/1/000002
# 2  ../../data/images/2/000001  ../../data/images/2/000002
# 3  ../../data/images/3/000001  ../../data/images/3/000002
# 4  ../../data/images/4/000001  ../../data/images/4/000002
#
#                       image_3                     image_4  \
# 0  ../../data/images/0/000003  ../../data/images/0/000004
# 1  ../../data/images/1/000003  ../../data/images/1/000004
# 2  ../../data/images/2/000003  ../../data/images/2/000004
# 3  ../../data/images/3/000003  ../../data/images/3/000004
# 4  ../../data/images/4/000003  ../../data/images/4/000004
#
#                       image_5                     image_6  \
# 0  ../../data/images/0/000005  ../../data/images/0/000006
# 1  ../../data/images/1/000005  ../../data/images/1/000006
# 2  ../../data/images/2/000005  ../../data/images/2/000006
# 3  ../../data/images/3/000005  ../../data/images/3/000006
# 4  ../../data/images/4/000005  ../../data/images/4/000006
#
#                       image_7                     image_8  \
# 0  ../../data/images/0/000007  ../../data/images/0/000008
# 1  ../../data/images/1/000007  ../../data/images/1/000008
# 2  ../../data/images/2/000007  ../../data/images/2/000008
# 3  ../../data/images/3/000007  ../../data/images/3/000008
# 4  ../../data/images/4/000007  ../../data/images/4/000008
#
#                       image_9
# 0  ../../data/images/0/000009
# 1  ../../data/images/1/000009
# 2  ../../data/images/2/000009
# 3  ../../data/images/3/000009
# 4  ../../data/images/4/000009

# %%
df_melted = pd.melt(df, 
                    id_vars='recipe_id', 
                    value_vars=list(df.columns[1:]),
                    var_name='column', 
                    value_name='value').sort_values(by=["recipe_id", "column"]).reset_index(drop=True)

df_melted.head()
# Out:
#     recipe_id   column                       value
# 15          0  image_1  ../../data/images/0/000001
# 20          0  image_2  ../../data/images/0/000002
# 25          0  image_3  ../../data/images/0/000003
# 30          0  image_4  ../../data/images/0/000004
# 35          0  image_5  ../../data/images/0/000005

# %% [markdown]
# ## Create image embeddings

# %%
df_all_images = df_melted[df_melted.column.str.startswith("image_")][["recipe_id", "value"]].reset_index(drop=True)
df_all_images.columns = ["recipe_id", "image_path"]

# %%
df_all_images
# Out:
#     recipe_id                  image_path
# 0           0  ../../data/images/0/000001
# 1           0  ../../data/images/0/000002
# 2           0  ../../data/images/0/000003
# 3           0  ../../data/images/0/000004
# 4           0  ../../data/images/0/000005
# 5           0  ../../data/images/0/000006
# 6           0  ../../data/images/0/000007
# 7           0  ../../data/images/0/000008
# 8           0  ../../data/images/0/000009
# 9           1  ../../data/images/1/000001
# 10          1  ../../data/images/1/000002
# 11          1  ../../data/images/1/000003
# 12          1  ../../data/images/1/000004
# 13          1  ../../data/images/1/000005
# 14          1  ../../data/images/1/000006
# 15          1  ../../data/images/1/000007
# 16          1  ../../data/images/1/000008
# 17          1  ../../data/images/1/000009
# 18          2  ../../data/images/2/000001
# 19          2  ../../data/images/2/000002
# 20          2  ../../data/images/2/000003
# 21          2  ../../data/images/2/000004
# 22          2  ../../data/images/2/000005
# 23          2  ../../data/images/2/000006
# 24          2  ../../data/images/2/000007
# 25          2  ../../data/images/2/000008
# 26          2  ../../data/images/2/000009
# 27          3  ../../data/images/3/000001
# 28          3  ../../data/images/3/000002
# 29          3  ../../data/images/3/000003
# 30          3  ../../data/images/3/000004
# 31          3  ../../data/images/3/000005
# 32          3  ../../data/images/3/000006
# 33          3  ../../data/images/3/000007
# 34          3  ../../data/images/3/000008
# 35          3  ../../data/images/3/000009
# 36          4  ../../data/images/4/000001
# 37          4  ../../data/images/4/000002
# 38          4  ../../data/images/4/000003
# 39          4  ../../data/images/4/000004
# 40          4  ../../data/images/4/000005
# 41          4  ../../data/images/4/000006
# 42          4  ../../data/images/4/000007
# 43          4  ../../data/images/4/000008
# 44          4  ../../data/images/4/000009

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
class ImageDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform):
        self.images = df["image_path"].reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images.iloc[idx]
        image = Image.open(img_path).convert("RGB")
        image = self.transform(image)
        return image

# %%
squeezenet = models.squeezenet1_0(pretrained=True)
set_parameter_requires_grad(squeezenet, True)

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, model):
        super(FeatureExtractor, self).__init__()
        self.features = model.features
        self.avg_pool2d = nn.AdaptiveAvgPool2d(1)

    def forward(self, x):
        x = self.features(x)
        x = self.avg_pool2d(x)
        x = x.squeeze()
        return x

# %%
feature_extractor = FeatureExtractor(squeezenet).to(device)

# %%
IMAGE_SIZE = 224

data_transforms = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.CenterCrop(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)

# %%
dataset = ImageDataset(df_all_images, data_transforms)

# %%
dataloader = torch.utils.data.DataLoader(
    dataset, batch_size=10, shuffle=False, num_workers=2
)

# %%
embeddings = []
for item in tqdm(dataloader):
    item = item.to(device)
    embeddings.append(feature_extractor(item))
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))

# %% [markdown]
# ### Persist results

# %%
df_embeddings = df_all_images.join(pd.DataFrame(torch.cat(embeddings).tolist(), index=df_all_images.index)).drop(["image_path"], axis=1)
df_embeddings
# Out:
#     recipe_id         0         1         2         3         4         5  \
# 0           0  1.312647  1.745611  0.024549  4.041584  0.282331  0.036875
# 1           0  1.421376  1.250723  3.132711  0.144188  2.020523  2.047225
# 2           0  0.137828  1.564686  0.667484  0.580247  0.069224  0.124425
# 3           0  0.710551  1.478248  0.963002  0.000000  0.085762  0.022721
# 4           0  0.024385  0.623414  0.007182  0.294297  0.000000  0.062329
# 5           0  0.817215  0.556298  1.512543  0.165556  7.005704  0.990555
# 6           0  0.241889  1.460734  0.636300  0.456060  0.526707  0.000000
