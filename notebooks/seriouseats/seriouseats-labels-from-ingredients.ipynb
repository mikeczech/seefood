# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

import os
import re
import pandas as pd
import altair as alt
import itertools
import sys
from sklearn.pipeline import Pipeline
from gensim import corpora

sys.path.append("..")
from seefood.data import BasicTextTransformer

pd.set_option("max_colwidth", 400)

# %%
import glob
import random
import base64

from PIL import Image
from io import BytesIO
from IPython.display import HTML

pd.set_option("display.max_colwidth", -1)


def get_thumbnail(path):
    i = Image.open(path).convert("RGB")
    i.thumbnail((224, 224), Image.LANCZOS)
    return i


def image_base64(im):
    if isinstance(im, str):
        im = get_thumbnail(im)
    with BytesIO() as buffer:
        im.save(buffer, "jpeg")
        return base64.b64encode(buffer.getvalue()).decode()


def image_formatter(im):
    return f'<img src="data:image/jpeg;base64,{image_base64(im)}">'

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("../data/seriouseats/seriouseats.csv")[
    ["title", "thumbnail", "ingredients"]
]
df["ingredients"] = df["ingredients"].map(lambda x: str(x).split("||||"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8312 entries, 0 to 8311
# Data columns (total 3 columns):
# title          8312 non-null object
# thumbnail      8312 non-null object
# ingredients    8312 non-null object
# dtypes: object(3)
# memory usage: 194.9+ KB

# %%
df.head()
# Out:
#                                            title  \
# 0  Jammy Fruit Bars
# 1  Balsamic Glazed Baby Back Ribs
# 2  The Best Meatball Pizza
# 3  Easy Pork Rillettes (Slow-Cooked Pork Spread)
# 4  Duck Pastrami
#
#                                                                                               thumbnail  \
# 0  https://www.seriouseats.com/2019/05/20190429-fruit-oat-bars-vicky-wasik-20-625x469.jpg
# 1  https://www.seriouseats.com/recipes/images/2016/07/20130519-252806-balsamic-glazed-ribs-625x469.jpg
# 2  https://www.seriouseats.com/recipes/images/2015/01/20150109-meatball-pizza-small-balls-8-625x469.jpg
# 3  https://www.seriouseats.com/recipes/images/2017/02/20170215-pork-rillettes-12-625x469.jpg
# 4  https://www.seriouseats.com/recipes/images/2013/02/20130227-242590-duck-pastrami.jpg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ingredients
# 0  [For the Dough:, 4 1/2 ounces old fashioned rolled oats, not quick cooking, instant, or thick cut (about 1 1/3 cup; 128g), 4 1/2 ounces all-purpose flour (about 1 cup, spooned; 128g), 6 ounces light brown sugar (about 3/4 cup, firmly packed; 170g), 1 teaspoon baking powder, 1 teaspoon (4g) Diamond Crystal kosher salt, plus more for sprinkling; for table salt, use about half as much by volume or the same weight, plus additional salt for sprinkling, 1/4 teaspoon baking soda, 1/4 teaspoon ground cinnamon, 6 ounces cold, unsalted butter, cut into 1/2-inch cubes (about 3/4 cup; 170g), 1 large egg, straight from the fridge (about 1 3/4 ounces; 50g), For the Filling:, 8 ounces jam (volume will vary; 225g) or 12 ounces "juicy" fruit, such as whole blueberries or raspberries, pitted cherries, sliced strawberries, or peeled and diced peaches (volume will vary; 340g), Lemon juice, to taste]
# 1  [For the Rub:, 2 tablespoons dark brown sugar, 2 tablespoons Kosher salt, 1 tablespoon granulated sugar, 1 tablespoon paprika, 1/2 teaspoon ground white pepper, 1/2 teaspoon ground black pepper, 1/2 teaspoon ground mustard, 1/2 teaspoon dried thyme, 1/2 teaspoon garlic powder, 1/2 teaspoon ground Szechuan peppercorns, 1/4 teaspoon cayenne pepper,  , 2 racks baby back ribs, 1 to 2 fist sized chunks of light smoking wood, like apple or cherry, 1 cup balsamic barbecue sauce,  , Type of fire: Indirect, Grill heat: Low]
# 2  [1 recipe Italian-American Meatballs in Red Sauce, prepared through step 5, including sauce, 5 tablespoons (75ml) extra-virgin olive oil, divided, 1 medium bunch fresh basil leaves, divided, 1 recipe New York–Style Pizza Dough, divided into 3 balls, proofed, and ready to stretch and top, 1 pound grated full-fat dry mozzarella cheese (450g; about 4 cups), Kosher salt, 1 1/2 ounces (45g) finely grated Pecorino Romano or Parmesan cheese]
# 3  [2 pounds boneless, skinless pork shoulder, cut into 1 1/2-inch chunks (about 1kg), Kosher salt, 1/2 cup vegetable oil, lard, or duck fat (120ml), 4 bay leaves, 6 fresh thyme sprigs, 2 large shallots, very roughly chopped, 4 medium cloves garlic, split in half, Freshly ground nutmeg, to taste]
# 4  [For the Cure:, 1/4 cup Kosher salt, 2 teaspoons ground black pepper, 2 teaspoons ground coriander, 2 teaspoons dark brown sugar, 1 teaspoon ground juniper berries, 3/4 teaspoon pink salt, 1/2 teaspoon ground ginger, 1/2 teaspoon granulated garlic, 1/2 teaspoon ground cloves,  , 4 pounds skin-on boneless duck breast (about 4 large breasts each),  , For the Rub:, 3 tablespoons coarsely ground black pepper, 1 1/2 tablespoons coarsely ground coriander seed, 2 teaspoons coarsely ground juniper berries, 1/2 teaspoon granulated garlic,  , 1to 2 fist-size chunks of light smoking wood, such as apple or cherry,  , Type of fire: Indirect, Grill heat: Low]

# %%
all_ingredients = set(itertools.chain(*df["ingredients"]))

# %%
def remove_content_in_braces(ingredient):
    match = re.search(r".*(\s\(.+\)).*", ingredient)
    if match:
        return ingredient.replace(match.group(1), "")
    return ingredient


def get_unit(ingredient):
    match = re.search(r"^(([0-9]+\s?)?([0-9]\/[0-9])?\s)(.*)$", ingredient)
    if match:
        return match.group(4)
    return None

# %%
all_ingredients_no_braces = [remove_content_in_braces(i) for i in all_ingredients]

# %%
pipeline = Pipeline(
    [
        (
            "basic_text",
            BasicTextTransformer(
                "ingredients",
                "p_ingredients",
                bigram_threshold=30,
                trigram_threshold=50,
            ),
        )
    ]
)

ingreds_df = pipeline.fit_transform(
    pd.DataFrame({"ingredients": all_ingredients_no_braces})
)
# Out:
# [nltk_data] Downloading package stopwords to /home/mike/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from collections import Counter

tokens = list(itertools.chain(*ingreds_df["p_ingredients"]))
counter = Counter(tokens)
counter.most_common(20)
# Out:
# [('cup', 12423),
#  ('tablespoon', 7638),
#  ('teaspoon', 5191),
#  ('pound', 3337),
#  ('inch', 2853),
#  ('oil', 2332),
#  ('ounce', 2307),
#  ('onion', 1857),
#  ('pepper', 1758),
#  ('butter', 1646),
#  ('juice', 1643),
#  ('sugar', 1604),
#  ('chicken', 1601),
#  ('cheese', 1500),
#  ('leave', 1451),
#  ('lemon', 1440),
#  ('piece', 1332),
#  ('clove', 1305),
#  ('ground', 1110),
#  ('water', 1071)]

# %%
INGREDIENT_COUNT_THRESHOLD = 30
least_common_ingredients = set(
    [i for i, count in counter.items() if count <= INGREDIENT_COUNT_THRESHOLD]
)

# %%
len(least_common_ingredients)
# Out:
# 3336

# %%
measure_unit = [
    "cup",
    "teaspoon",
    "tablespoon",
    "bund",
    "pound",
    "knob",
    "slice",
    "cut",
    "ounce",
    "inch",
    "leave",
    "piece",
    "ground",
    "clove",
    "dice",
    "bunch",
    "cubes",
    "medium",
    "sections",
    "cubed",
]

# %%
ingreds_df["pp_ingredients"] = ingreds_df["p_ingredients"].map(
    lambda x: [
        i for i in x if i not in measure_unit and i not in least_common_ingredients
    ]
)

# %%
ingreds_df.sample(20)
# Out:
#                                                                          ingredients  \
# 46470  2 slices hardwood-smoked bacon
# 31312  1 can peeled whole tomatoes, preferably San Marzano
# 32645  2 leeks, white parts only, chopped
# 47683  Sugar for sprinkling the pie before baking
# 25523  1 cup all-purpose flour
# 43943  1 recipe Santa Maria-Style Salsa
# 26226  3/4 cup plus 2 tablespoons unbleached all purpose flour, sifted
# 47698  Lime wheels, mint leaves, and large ice block or large ice cubes, for garnish
# 29234  4 tablespoons unsalted butter or margarine, melted
# 26319  3 tablespoons unsalted butter, cut into cubes
# 43137  4 strips of bacon, chopped
# 31762  3/4 kosher teaspoon salt
# 19673  rounds of toasted bread
# 36182  freshly ground pepper
# 12458  1 1/2 pounds salmon fillet, cut into 1-inch cubes
# 37619  1/2 teaspoon fresh or dried sage
# 42671  1/4 cup peeled and diced jicama
# 15741  2 slices bacon, chopped finely
# 14573  1/4 teaspoon ground coriander
# 31487  1 teaspoon dry mango powder
#
#                               p_ingredients                pp_ingredients
# 46470  [hardwood, bacon]                     [bacon]
# 31312  [tomato]                              [tomato]
# 32645  [part]                                [part]
# 47683  [sugar, sprinkling, pie, baking]      [sugar, sprinkling, baking]
# 25523  [cup, purpose_flour]                  [purpose_flour]
# 43943  [recipe, santa, maria, style, salsa]  [recipe, style, salsa]
# 26226  [cup, tablespoon, purpose_flour]      [purpose_flour]
# 47698  [lime, wheel, mint, ice, ice, cube]   [lime, mint, ice, ice, cube]
# 29234  [tablespoon, butter, margarine]       [butter]
# 26319  [tablespoon, butter, cut, cube]       [butter, cube]
# 43137  [strip, bacon]                        [strip, bacon]
# 31762  [teaspoon, salt]                      [salt]
# 19673  [round, bread]                        [round, bread]
# 36182  [ground, pepper]                      [pepper]
# 12458  [pound, salmon_fillet, inch, cube]    [salmon_fillet, cube]
# 37619  [teaspoon, sage]                      [sage]
# 42671  [cup, jicama]                         []
# 15741  [bacon]                               [bacon]
# 14573  [teaspoon, ground, coriander]         [coriander]
# 31487  [teaspoon, mango, powder]             [mango, powder]

# %%
set(itertools.chain(*ingreds_df["pp_ingredients"]))
# Out:
# {'adobo',
#  'allspice',
#  'almond',
#  'ancho',
#  'anchovy',
#  'anchovy_fillet',
#  'apple',
#  'apple_cider',
#  'apricot',
#  'arugula',
#  'asian_fish',
#  'asparagus',
#  'avocado',
#  'baby',
#  'baby_arugula',
#  'baby_spinach',
#  'bacon',
#  'bag',
#  'baguette',
#  'baking',
#  'baking_soda',
#  'ball',
#  'balsamic_vinegar',
#  'banana',
#  'barbecue',
#  'base',
#  'basil',
#  'bay',
#  'bean',
#  'bean_paste',
#  'beef',
#  'beef_chuck',
#  'beer',
#  'beet',
#  'bell',
#  'bell_pepper',
#  'berry',
#  'bias',
#  'bite_size',
#  'bittersweet_chocolate',
#  'blood_orange',
#  'blueberry',
#  'boiling',
#  'bone',
#  'boneless',
#  'boneless_skinless',
#  'bottom',
#  'bourbon',
#  'bowl',
#  'box',
#  'brandy',
#  'bread',
#  'bread_crumbs',
#  'breadcrumb',
#  'breast',
#  'breast_halve',
#  'brine',
#  'brisket',
#  'broccoli',
#  'broth',
#  'brussels_sprout',
#  'bun',
#  'bunche',
#  'butter',
#  'buttermilk',
#  'butternut_squash',
#  'button_mushroom',
#  'cabbage',
#  'cake',
#  'can',
#  'canola',
#  'cap',
#  'caper',
#  'cardamom',
#  'carrot',
#  'cashews',
#  'casing',
#  'cayenne',
#  'celery',
#  'center',
#  'cheddar',
#  'cheese',
#  'cherry',
#  'cherry_tomatoe',
#  'chervil',
#  'chicken',
#  'chickpea',
#  'chile',
#  'chili',
#  'chilie',
#  'chilis',
#  'chilli',
#  'chip',
#  'chipotle',
#  'chive',
#  'chocolate',
#  'chocolate_chip',
#  'choice',
#  'chop',
#  'chorizo',
#  'chunk',
#  'ciabatta',
#  'cider_vinegar',
#  'cilantro',
#  'cinnamon',
#  'cinnamon_stick',
#  'clam',
#  'cocoa_powder',
#  'coconut',
#  'cod',
#  'coffee',
#  'confectioner',
#  'cookie',
#  'cooking',
#  'core',
#  'coriander',
#  'coriander_seed',
#  'corn',
#  'corn_kernel',
#  'corn_tortillas',
#  'cornmeal',
#  'cornstarch',
#  'country',
#  'cracked_black',
#  'cracker',
#  'cranberry',
#  'cream',
#  'creamy_peanut',
#  'creme_fraiche',
#  'cremini_mushroom',
#  'crosswise',
#  'crumbled_feta',
#  'crust',
#  'crusty_bread',
#  'cube',
#  'cucumber',
#  'cumin',
#  'curry_paste',
#  'curry_powder',
#  'dash',
#  'deep_frying',
#  'deveined',
#  'dijon_mustard',
#  'dill',
#  'dough',
#  'drumstick',
#  'duck',
#  'dusting',
#  'ear',
#  'egg',
#  'eggplant',
#  'end',
#  'ends_trimmed',
#  'fat',
#  'fennel',
#  'fennel_bulb',
#  'feta',
#  'fig',
#  'filet',
#  'fillet',
#  'filling',
#  'firm_tofu',
#  'fish',
#  'flake',
#  'flank_steak',
#  'flesh',
#  'floret',
#  'flour',
#  'flower',
#  'food_processor',
#  'fruit',
#  'garlic',
#  'garnish',
#  'ghee',
#  'gin',
#  'ginger',
#  'glaze',
#  'gluten_free',
#  'goat',
#  'good_quality',
#  'grain',
#  'gram',
#  'grape',
#  'grapefruit',
#  'grapeseed',
#  'gravy',
#  'greasing',
#  'greek_yogurt',
#  'green',
#  'green_part',
#  'gruyere',
#  'half',
#  'half_moon',
#  'ham',
#  'hand',
#  'handful',
#  'harissa',
#  'hazelnut',
#  'head',
#  'head_cauliflower',
#  'heavy_cream',
#  'herb',
#  'high_quality',
#  'hole',
#  'homemade',
#  'honey',
#  'horseradish',
#  'hour',
#  'ice',
#  'iceberg_lettuce',
#  'ingredient',
#  'italian_sausage',
#  'jack',
#  'jalapeno',
#  'jam',
#  'jar',
#  'jasmine',
#  'juice',
#  'kale',
#  'ketchup',
#  'kg',
#  'kimchi',
#  'knife',
#  'kosher_salt',
#  'lamb',
#  'lard',
#  'layer',
#  'lb',
#  'leek',
#  'leg',
#  'lemon',
#  'lemongrass',
#  'length',
#  'lengthwise',
#  'lentil',
#  'lettuce',
#  'light',
#  'light_brown',
#  'light_green_part',
#  'lightly_beaten',
#  'lime',
#  'liqueur',
#  'liquid',
#  'liver',
#  'loaf',
#  'long_grain',
#  'mandoline',
#  'mango',
#  'maple_syrup',
#  'marinade',
#  'matchstick',
#  'mayonnaise',
#  'meat',
#  'mexican_crema',
#  'microplane',
#  'microplane_grater',
#  'milk',
#  'mint',
#  'minute',
#  'mirin',
#  'miso',
#  'miso_paste',
#  'mix',
#  'mixture',
#  'ml',
#  'molasse',
#  'monterey_jack',
#  'mozzarella',
#  'mushroom',
#  'mussel',
#  'mustard',
#  'napa_cabbage',
#  'neck',
#  'noodle',
#  'nut',
#  'nutmeg',
#  'oil',
#  'olive',
#  'onion',
#  'optional',
#  'orange',
#  'oregano',
#  'oyster',
#  'package',
#  'palm',
#  'pan',
#  'pancetta',
#  'paprika',
#  'parmesan',
#  'parmigiano_reggiano',
#  'parsley',
#  'parsnip',
#  'part',
#  'pasta',
#  'paste',
#  'pastry',
#  'pea',
#  'peach',
#  'peanut',
#  'pear',
#  'pecan',
#  'pecorino',
#  'pecorino_romano',
#  'peel',
#  'penne',
#  'pepper',
#  'peppercorn',
#  'pesto',
#  'pickle',
#  'pinch',
#  'pine_nut',
#  'pineapple',
#  'pint',
#  'pistachio',
#  'pita',
#  'plain_yogurt',
#  'plum',
#  'plum_tomatoes',
#  'poblano',
#  'pod',
#  'pole',
#  'pomegranate',
#  'pork',
#  'pork_belly',
#  'pork_chop',
#  'pork_shoulder',
#  'potato',
#  'powder',
#  'prosciutto',
#  'pumpkin',
#  'puree',
#  'pureed',
#  'purpose_flour',
#  'quart',
#  'quarter',
#  'quinoa',
#  'radish',
#  'raisin',
#  'raspberry',
#  'recipe',
#  'rhubarb',
#  'rib',
#  'ribbon',
#  'rice',
#  'ricotta',
#  'rind',
#  'ring',
#  'roast',
#  'roasted_peanut',
#  'roll',
#  'romaine_lettuce',
#  'room_temperature',
#  'root',
#  'rosemary',
#  'round',
#  'rub',
#  'rum',
#  'russet_potatoe',
#  'rye',
#  'sage',
#  'sake',
#  'salad',
#  'salmon',
#  'salmon_fillet',
#  'salsa',
#  'salt',
#  'sandwich',
#  'sauce',
#  'sausage',
#  'scallion',
#  'sea',
#  'seasoning',
#  'section',
#  'seed',
#  'seeded',
#  'segment',
#  'seltzer',
#  'serrano',
#  'serving',
#  'sesame',
#  'shallot',
#  'shaoxing_wine',
#  'sharp_cheddar',
#  'sheet',
#  'shell',
#  'sherry',
#  'shiitake_mushroom',
#  'shrimp',
#  'sichuan_peppercorn',
#  'side',
#  'simple_syrup',
#  'sirloin',
#  'size',
#  'skillet',
#  'skin',
#  'skirt_steak',
#  'slivered_almond',
#  'smoked_paprika',
#  'snap_peas',
#  'sour_cream',
#  'spaghetti',
#  'spice',
#  'spinach',
#  'split',
#  'sprig',
#  'spring',
#  'sprinkling',
#  'squash',
#  'sriracha',
#  'stalk',
#  'stalk_celery',
#  'stalks_celery',
#  'steak',
#  'stem',
#  'stemmed_seeded',
#  'stick',
#  'stock',
#  'store_bought',
#  'strawberry',
#  'strip',
#  'style',
#  'sugar',
#  'summer_squash',
#  'sunflower',
#  'superfine',
#  'swiss_chard',
#  'syrup',
#  'tabasco',
#  'table',
#  'tahini',
#  'tarragon',
#  'tart',
#  'taste',
#  'tbsp',
#  'tea',
#  'tender',
#  'tender_stems',
#  'tenderloin',
#  'thai',
#  'thigh',
#  'thyme',
#  'tip',
#  'toast',
#  'tofu',
#  'tomato',
#  'top',
#  'topping',
#  'tortilla',
#  'trout',
#  'tsp',
#  'tuna',
#  'turkey',
#  'use',
#  'vanilla',
#  'vanilla_extract',
#  'veal',
#  'vegetable',
#  'vermouth',
#  'vinaigrette',
#  'vinegar',
#  'vodka',
#  'volume',
#  'walnut',
#  'water',
#  'watercress',
#  'watermelon',
#  'wedge',
#  'weight',
#  'wheat',
#  'whipped_cream',
#  'white',
#  'wine',
#  'wing',
#  'worcestershire',
#  'yogurt',
#  'yukon_gold_potatoe',
#  'zest',
#  'zucchini'}
